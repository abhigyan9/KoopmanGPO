# %%
# This script uses class definition to store, access and compute GP Observables in an organized manner

import GPKoopman as gpk
import torch
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import display, clear_output
import math

print('Imported PyTorch version:', torch.__version__)
print('Imported NumPy version:', np.__version__)
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# Imported PyTorch version: 2.5.1+cu124
# Imported NumPy version: 2.2.2
# True
# NVIDIA GeForce RTX 4070 Ti SUPER

# %% [markdown]
# ### Testing Cells

# %% [markdown]
# ### Cost Function Definition

# %%
# Multi-Trajectory Cost Function Definition

def get_cost_ABC(Z, X, Xplus, U, Xtrain, manager, nT=1, lambda1=1.0, lambda2=1.0, lambda3=1.0):
    """
    Computes the cost function as defined in the Word doc, with different GP Kernel hyperparameters for
    each observable.

    Args:
        Z: Tensor of shape (r**n, p), decision variable, required grad
        X: Tensor of shape (n, nT*N), dataset of N steps from all trajectories
        Xall: Tensor of shape (n, nT*(N+1)), complete training dataset
        Xtrain: Tensor of shape (n, r**n), flattened set of gridpoints for training GPOs
        manager: Object of class GPObservablesManager (manager for all Gaussian Process based Observable functions)
        nT: float, number of trajectories in training dataset
        lambda1: float, Weighting for NLPD
        lambda2: float, Weightining for Linearity enforcement in lifted state
    """
    
    N = (X.shape[1])//nT    # Number of time steps in each trajectory
    p = Z.shape[1]          # Number of Observables
    l = Z.shape[0]//nT      # Decision Horizon
    nx = X.shape[0]         # Dimensionality of original system
    nu = U.shape[0]

    for i in range(p):
        manager.train_observable(i, Xtrain, Z[:,i])

    # Lifting X and Xplus to higher dimension using trained GPOs
    M = torch.empty((p,N*nT))
    Mplus = torch.empty((p,N*nT))
    
    #Mall = torch.empty((p,(N+1)*nT))
    for i in range(p):
        M[i,:] = torch.transpose(manager.predict_mean(i, X), dim0=0, dim1=-1)
        Mplus[i,:] = torch.transpose(manager.predict_mean(i, Xplus), dim0=0, dim1=-1)
    
    # Compute C(z) and A(z)
    M_full = torch.vstack((M,U))
    M_pinv = torch.linalg.pinv(M_full)
    KO_eDMDc = Mplus @ M_pinv
    Az = KO_eDMDc[:, 0:p]
    Bz = KO_eDMDc[:, p:]
    Cz = X @ (torch.linalg.pinv(M))
        
    # Cost term 1: Negative Log Predictive Density (penalize uncertainty and confidently wrong models)
    NormNLPD = 0.0
    for j in range(nT):
        TrajNLPD = 0.0
        vz_k = torch.empty((p,N - 2 - l), device=M.device)
        for i in range(p):
            vz_k[i, :] = torch.clamp(torch.diag(manager.predict_covariance(i, X[:, j*N + l + 1:(j+1)*N-1])).view(1,N-2-l), min=1e-6)
        
        # for k in range(N-2-l):        
        #     vx_next = torch.diag(Cz @ Az @ torch.diag(vz_k[:, k]) @ Az.T @ Cz.T).view(n,1)
        #     #vx_next = torch.clamp(vx_next,min=1e-8)
        #     TrajNLPD += torch.norm(((X[:, j*N + l + 1 + k+1] - Cz @ Az @ M[:, j*N + l + 1 + k]) ** 2 / (lambda3 + vx_next) + torch.log(lambda3 + vx_next)))
        for k in range(N-2-l):        
            vx_next = torch.diag(Cz @ Az @ torch.diag(vz_k[:, k]) @ Az.T @ Cz.T).view(nx,1)
            #vx_next = torch.clamp(vx_next, min=1e-8)  # Ensure positivity
            xhat_plus = Cz @ (Az @ M[:, j*N + l+1 + k] + Bz @ U[:, j*N + l+1 + k])
            error_term = ((X[:, j*N + l+1 + k+1] - xhat_plus) ** 2) / (lambda3 + vx_next)
            log_term = torch.log(lambda3 + vx_next)
            # Sum the contributions from all dimensions
            TrajNLPD += torch.sum(error_term + log_term)


        NormNLPD += TrajNLPD
    
    # Cost term 1: Multi-Trajectory Prediction Error Minimization
    # NormPEM = 0.0
    # for j in range(nT):
    #     TrajPEM = 0.0
    #     for k in range(N - 1):
    #         pred_error = X[:, j*N + (k+1)] - Cz @ (torch.linalg.matrix_power(Az,k+1)) @ M[:,j*N]   # multi-step at X (with Cz)
    #         TrajPEM += torch.norm(pred_error)
    #     NormPEM += TrajPEM

    # Cost Term 2: Linearity Enforcement
    NormLEP = 0.0
    for j in range(nT):
        TrajLEP = 0.0
        for k in range(l-1):
            z_next = Az @ torch.transpose(Z[j*l + k, :], dim0=0, dim1=-1) + Bz @ U[:, j*N + k]
            lin_error = torch.transpose(Z[j*l + k + 1, :], dim0=0, dim1=-1) - z_next
            TrajLEP += torch.norm(lin_error)
        NormLEP += TrajLEP
    
    # Weighted sum of terms
    cost = (lambda1 * NormNLPD / ((N-l) * nT)) + (lambda2 * NormLEP / (l * nT))
    return cost

# %% [markdown]
# # Execution Cells

# %% [markdown]
# ## Data Loading

# %%
# Allowed system names -
# "Unforced Duffing"
# "Unforced Duffing"_right - domain restricted to right equilibrium point only
# "van der Pol"
# "Simple Pendulum"
# "Lorenz"
# "Lotka Volterra"

# "Duffing"
# "Pendulum"
# "Cart"

system_name = 'Pendulum'
data = torch.load(f"Data/{system_name}_data.pt", weights_only=True)

SimData = data["trajectories"] # Shape: (num_trajectories, state_dim, num_steps)
SimInput = data["inputs"]
ts = data["sample_time"]
#num_trajectories = data["num_trajectories"]
num_trajectories = SimData.shape[0]
N = data["num_steps"]
nTrain = math.floor(num_trajectories * 0.5)
nTest = math.floor(num_trajectories * 0.2)

N = 150
SimData = SimData[:,:,:N+1]
SimInput = SimInput[:,:,:N+1]

# %%
# Phase Diagram from all IC simulation
for j in range(SimData.shape[0]):
    plt.plot(SimData[j,0,:], SimData[j,1,:], alpha=0.5, color='blue')
    plt.plot(SimData[j,0,0], SimData[j,1,0], 'o', color='red')

plt.grid()
plt.xlabel('X1')
plt.ylabel('X2')
plt.title(f'All Trajectories: {system_name}')
plt.show()

# %%
# # Create a 3D figure
# fig = plt.figure(figsize=(8, 6))
# ax = fig.add_subplot(111, projection='3d')

# # Plot all trajectories
# for i in range(num_trajectories):
#     ax.plot(SimData[i, 0, :], SimData[i, 1, :], SimData[i, 2, :], alpha=0.7, label=f'Traj {i+1}' if i < 5 else "")
#     ax.plot(SimData[i, 0, 0], SimData[i, 1, 0], SimData[i, 2, 0], alpha=0.7, marker='o', linestyle='None')

# # Labels and title
# ax.set_xlabel("State X1")
# ax.set_ylabel("State X2")
# ax.set_zlabel("State X3")
# ax.set_title("3D Plot of All Trajectories in SimData")

# plt.show()

# %% [markdown]
# ## Optimization Section

# %% [markdown]
# ### Find Optimal Z Values

# %%
SimData = SimData.float()
SimInput = SimInput.float()
n = SimData.shape[1]
nu = SimInput.shape[1]

p = 30  # number of lifted states
l = 30  # decision horizon for each lifted state
r = 10   # resolution along all dimensions

Xall = torch.cat([SimData[j, :, :] for j in range(nTrain)], dim=1)      # Concatenated total matrix
X = torch.cat([SimData[j, :, 0:N] for j in range(nTrain)], dim=1)       # Concatenated Data matrix
U = torch.cat([SimInput[j, :, 0:N] for j in range(nTrain)], dim=1).view(nu,nTrain*N)    # Concatenated Input Matrix
Xplus = torch.cat([SimData[j, :, 1:] for j in range(nTrain)], dim=1)    # Time-shifted Data matrix
ICsetTrain = torch.cat([SimData[j, :, 0].view(n,1) for j in range(nTrain)], dim=1)    # Random IC set for training
ICsetTest = torch.cat([SimData[j, :, 0].view(n,1) for j in range(nTrain, nTrain + nTest)], dim=1)  # Random IC set for testing

# Options: 'Horizon' | 'Grid'
trainMethod = 'Horizon'

# Initialize GP training-grid and decision variables
if trainMethod == 'Horizon':
    Xtrain = torch.cat([X[:,j*N:j*N+l] for j in range(nTrain)],dim=1)
    Z = torch.rand(Xtrain.shape[1], p, requires_grad=True)
    ObsManager = gpk.GPObservablesManager()
    for i in range(p):
        ObsManager.add_observable(index=i, d=n, ns=l*nTrain, kernel_types=['Gaussian'],noise=1e-6, m=500)
        
elif trainMethod == 'Grid':
    # GPO Training Grid
    gridpoints0 = torch.linspace(-4., 4., steps=r)
    gridpoints1 = torch.linspace(-4., 4., steps=r)
    grid0, grid1 = torch.meshgrid(gridpoints0, gridpoints1, indexing='xy')
    Xtrain = torch.stack([torch.flatten(grid0), torch.flatten(grid1)])
    Z = torch.rand(r**n, p, requires_grad=True)
    ObsManager = gpk.GPObservablesManager()
    for i in range(p):
        ObsManager.add_observable(index=i, d=n, ns=r**n, kernel_types=['Gaussian'],noise=1e-6)

else:
    raise ValueError(f'Unrecognized GP Training method {trainMethod}')


ObsManager.set_random_hyperparameters(scale=0.01)
print('Observable Hyperparameters have been randomized')
# Out:
# Observable Hyperparameters have been randomized

# %%
# Plot the Xtrain points in space
for i in range(Xtrain.shape[1]):
    plt.plot(Xtrain[0,i], Xtrain[1,i], linestyle='None', marker='x', color='red', alpha=0.5)

plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Inducing Points (Xtrain)')
plt.grid()
plt.show()

# %%
cost1 = get_cost_ABC(Z, X, Xplus, U, Xtrain, ObsManager, nT=nTrain, lambda1=1., lambda2=0., lambda3=0.)
cost2 = get_cost_ABC(Z, X, Xplus, U, Xtrain, ObsManager, nT=nTrain, lambda1=0., lambda2=1., lambda3=0.)
print(f'Initial Cost-1 is {cost1.cpu().detach()}')
print(f'Initial Cost-2 is {cost2.cpu().detach()}')
# Out:
# Initial Cost-1 is 9995913216.0
# Initial Cost-2 is 3.040376901626587

# %%
Theta = ObsManager.get_all_params()
Theta
# Out:
# tensor([[0.0061, 0.0099],
#         [0.0083, 0.0073],
#         [0.0033, 0.0031],
#         [0.0023, 0.0036],
#         [0.0055, 0.0027],
#         [0.0052, 0.0033],
#         [0.0038, 0.0022],
#         [0.0026, 0.0074],
#         [0.0092, 0.0010],
#         [0.0068, 0.0033],
#         [0.0034, 0.0038],
#         [0.0092, 0.0029],
#         [0.0022, 0.0074],
#         [0.0014, 0.0070],
#         [0.0044, 0.0014],
#         [0.0052, 0.0045],
#         [0.0063, 0.0041],
#         [0.0058, 0.0053],
#         [0.0067, 0.0017],
#         [0.0068, 0.0028],
#         [0.0023, 0.0004],
#         [0.0017, 0.0064],
#         [0.0074, 0.0039],
#         [0.0030, 0.0008],
#         [0.0099, 0.0057],
#         [0.0089, 0.0079],
#         [0.0057, 0.0003],
#         [0.0073, 0.0079],
#         [0.0075, 0.0046],
#         [0.0075, 0.0010]])

# %%
print(f'Total Observables available: {gpk.GPObservable.count_Observables()}')

# Optimization Parameters
max_iter = 1500
learn_rate = 0.015   # Learning Rate    
err_thresh = 0.01    # Target Cost
patience = 5       # Number of iterations to monitor for significant change
min_delta = 5e-1    # Minimum required decrease in cost for significance

optimizer = torch.optim.Adam([Z, ObsManager.get_all_params()], lr=learn_rate)    # Optimizer  

print('Starting Iteration Loop!')
cost_history = []
iter = 0
count_insignificant = 0

while iter < max_iter:
    optimizer.zero_grad()  # Clear gradients
    cost = get_cost_ABC(Z, X, Xplus, U, Xtrain, ObsManager, nT=nTrain, lambda1=1e-2, lambda2=100., lambda3=0.)   # compute cost
    cost_history.append(cost.item())    # add to cost history
    cost.backward(retain_graph=True)    # backpropagate
    optimizer.step()    # gradient descent step

    print(f"Iteration {iter + 1}/{max_iter} with {count_insignificant} Insignificant Iterations")
    print(f"Cost: {cost.item()}")

    # Stopping conditions
    if cost.item() < err_thresh:
        print("Stopping: Error threshold reached.")
        break

    # Check for significant improvement
    if iter > patience:
        error_change = cost_history[-patience] - cost_history[-1]
        if error_change < min_delta or error_change < 0:
            count_insignificant += 1
        else:
            count_insignificant = 0

        if count_insignificant >= patience:
            print("Stopping: No significant improvement over consecutive iterations.")
            break

    # Increment iteration
    iter += 1


if iter == max_iter:
    print(f'Stopping: Reached maximum number of iterations = {iter}.')


optimal_Z = Z.detach()

print('Optimization Complete.')
print("Final Cost:", cost.item())
# Out:
# Total Observables available: 30
# Starting Iteration Loop!
# Iteration 1/1500 with 0 Insignificant Iterations
# Cost: 99959440.0
# Iteration 2/1500 with 0 Insignificant Iterations
# Cost: 14125761.0
# Iteration 3/1500 with 0 Insignificant Iterations
# Cost: 6702006.5
# Iteration 4/1500 with 0 Insignificant Iterations
# Cost: 4207295.0
# Iteration 5/1500 with 0 Insignificant Iterations
# Cost: 3037276.0
# Iteration 6/1500 with 0 Insignificant Iterations
# Cost: 2375740.5
# Iteration 7/1500 with 0 Insignificant Iterations
# Cost: 1954540.875
# Iteration 8/1500 with 0 Insignificant Iterations
# Cost: 1663725.75
# Iteration 9/1500 with 0 Insignificant Iterations
# Cost: 1450944.75
# Iteration 10/1500 with 0 Insignificant Iterations
# Cost: 1288403.0
# Iteration 11/1500 with 0 Insignificant Iterations
# Cost: 1160080.0
# Iteration 12/1500 with 0 Insignificant Iterations
# Cost: 1056124.125
# Iteration 13/1500 with 0 Insignificant Iterations
# Cost: 970145.1875
# Iteration 14/1500 with 0 Insignificant Iterations
# Cost: 897818.3125
# Iteration 15/1500 with 0 Insignificant Iterations
# Cost: 836113.4375
# Iteration 16/1500 with 0 Insignificant Iterations
# Cost: 782836.75
# Iteration 17/1500 with 0 Insignificant Iterations
# Cost: 736363.0625
# Iteration 18/1500 with 0 Insignificant Iterations
# Cost: 695459.1875
# Iteration 19/1500 with 0 Insignificant Iterations
# Cost: 659174.75
# Iteration 20/1500 with 0 Insignificant Iterations
# Cost: 626763.8125
# Iteration 21/1500 with 0 Insignificant Iterations
# Cost: 597629.5625
# Iteration 22/1500 with 0 Insignificant Iterations
# Cost: 571293.25
# Iteration 23/1500 with 0 Insignificant Iterations
# Cost: 547362.8125
# Iteration 24/1500 with 0 Insignificant Iterations
# Cost: 525517.9375
# Iteration 25/1500 with 0 Insignificant Iterations
# Cost: 505487.8125
# Iteration 26/1500 with 0 Insignificant Iterations
# Cost: 487051.5625
# Iteration 27/1500 with 0 Insignificant Iterations
# Cost: 470018.0
# Iteration 28/1500 with 0 Insignificant Iterations
# Cost: 454225.9375
# Iteration 29/1500 with 0 Insignificant Iterations
# Cost: 439539.84375
# Iteration 30/1500 with 0 Insignificant Iterations
# Cost: 425839.34375
# Iteration 31/1500 with 0 Insignificant Iterations
# Cost: 413022.09375
# Iteration 32/1500 with 0 Insignificant Iterations
# Cost: 401001.78125
# Iteration 33/1500 with 0 Insignificant Iterations
# Cost: 389699.78125
# Iteration 34/1500 with 0 Insignificant Iterations
# Cost: 379048.875
# Iteration 35/1500 with 0 Insignificant Iterations
# Cost: 368987.875
# Iteration 36/1500 with 0 Insignificant Iterations
# Cost: 359468.78125
# Iteration 37/1500 with 0 Insignificant Iterations
# Cost: 350440.21875
# Iteration 38/1500 with 0 Insignificant Iterations
# Cost: 341864.34375
# Iteration 39/1500 with 0 Insignificant Iterations
# Cost: 333703.1875
# Iteration 40/1500 with 0 Insignificant Iterations
# Cost: 325924.5625
# Iteration 41/1500 with 0 Insignificant Iterations
# Cost: 318499.21875
# Iteration 42/1500 with 0 Insignificant Iterations
# Cost: 311399.78125
# Iteration 43/1500 with 0 Insignificant Iterations
# Cost: 304604.15625
# Iteration 44/1500 with 0 Insignificant Iterations
# Cost: 298089.28125
# Iteration 45/1500 with 0 Insignificant Iterations
# Cost: 291837.375
# Iteration 46/1500 with 0 Insignificant Iterations
# Cost: 285829.5625
# Iteration 47/1500 with 0 Insignificant Iterations
# Cost: 280051.0625
# Iteration 48/1500 with 0 Insignificant Iterations
# Cost: 274486.71875
# Iteration 49/1500 with 0 Insignificant Iterations
# Cost: 269123.84375
# Iteration 50/1500 with 0 Insignificant Iterations
# Cost: 263950.0625
# Iteration 51/1500 with 0 Insignificant Iterations
# Cost: 258954.296875
# Iteration 52/1500 with 0 Insignificant Iterations
# Cost: 254126.671875
# Iteration 53/1500 with 0 Insignificant Iterations
# Cost: 249457.625
# Iteration 54/1500 with 0 Insignificant Iterations
# Cost: 244938.140625
# Iteration 55/1500 with 0 Insignificant Iterations
# Cost: 240561.1875
# Iteration 56/1500 with 0 Insignificant Iterations
# Cost: 236319.34375
# Iteration 57/1500 with 0 Insignificant Iterations
# Cost: 232204.171875
# Iteration 58/1500 with 0 Insignificant Iterations
# Cost: 228212.84375
# Iteration 59/1500 with 0 Insignificant Iterations
# Cost: 224336.4375
# Iteration 60/1500 with 0 Insignificant Iterations
# Cost: 220570.234375
# Iteration 61/1500 with 0 Insignificant Iterations
# Cost: 216909.890625
# Iteration 62/1500 with 0 Insignificant Iterations
# Cost: 213350.53125
# Iteration 63/1500 with 0 Insignificant Iterations
# Cost: 209887.6875
# Iteration 64/1500 with 0 Insignificant Iterations
# Cost: 206516.5625
# Iteration 65/1500 with 0 Insignificant Iterations
# Cost: 203234.875
# Iteration 66/1500 with 0 Insignificant Iterations
# Cost: 200036.953125
# Iteration 67/1500 with 0 Insignificant Iterations
# Cost: 196921.46875
# Iteration 68/1500 with 0 Insignificant Iterations
# Cost: 193883.28125
# Iteration 69/1500 with 0 Insignificant Iterations
# Cost: 190920.21875
# Iteration 70/1500 with 0 Insignificant Iterations
# Cost: 188030.484375
# Iteration 71/1500 with 0 Insignificant Iterations
# Cost: 185209.40625
# Iteration 72/1500 with 0 Insignificant Iterations
# Cost: 182455.90625
# Iteration 73/1500 with 0 Insignificant Iterations
# Cost: 179767.125
# Iteration 74/1500 with 0 Insignificant Iterations
# Cost: 177140.546875
# Iteration 75/1500 with 0 Insignificant Iterations
# Cost: 174574.875
# Iteration 76/1500 with 0 Insignificant Iterations
# Cost: 172066.765625
# Iteration 77/1500 with 0 Insignificant Iterations
# Cost: 169615.703125
# Iteration 78/1500 with 0 Insignificant Iterations
# Cost: 167218.140625
# Iteration 79/1500 with 0 Insignificant Iterations
# Cost: 164874.015625
# Iteration 80/1500 with 0 Insignificant Iterations
# Cost: 162580.53125
# Iteration 81/1500 with 0 Insignificant Iterations
# Cost: 160336.6875
# Iteration 82/1500 with 0 Insignificant Iterations
# Cost: 158140.859375
# Iteration 83/1500 with 0 Insignificant Iterations
# Cost: 155990.8125
# Iteration 84/1500 with 0 Insignificant Iterations
# Cost: 153886.40625
# Iteration 85/1500 with 0 Insignificant Iterations
# Cost: 151825.265625
# Iteration 86/1500 with 0 Insignificant Iterations
# Cost: 149806.765625
# Iteration 87/1500 with 0 Insignificant Iterations
# Cost: 147829.765625
# Iteration 88/1500 with 0 Insignificant Iterations
# Cost: 145892.140625
# Iteration 89/1500 with 0 Insignificant Iterations
# Cost: 143993.4375
# Iteration 90/1500 with 0 Insignificant Iterations
# Cost: 142132.765625
# Iteration 91/1500 with 0 Insignificant Iterations
# Cost: 140308.421875
# Iteration 92/1500 with 0 Insignificant Iterations
# Cost: 138520.421875
# Iteration 93/1500 with 0 Insignificant Iterations
# Cost: 136766.6875
# Iteration 94/1500 with 0 Insignificant Iterations
# Cost: 135046.984375
# Iteration 95/1500 with 0 Insignificant Iterations
# Cost: 133359.796875
# Iteration 96/1500 with 0 Insignificant Iterations
# Cost: 131704.96875
# Iteration 97/1500 with 0 Insignificant Iterations
# Cost: 130081.390625
# Iteration 98/1500 with 0 Insignificant Iterations
# Cost: 128488.015625
# Iteration 99/1500 with 0 Insignificant Iterations
# Cost: 126923.953125
# Iteration 100/1500 with 0 Insignificant Iterations
# Cost: 125389.0703125
# Iteration 101/1500 with 0 Insignificant Iterations
# Cost: 123882.3984375
# Iteration 102/1500 with 0 Insignificant Iterations
# Cost: 122402.7890625
# Iteration 103/1500 with 0 Insignificant Iterations
# Cost: 120950.09375
# Iteration 104/1500 with 0 Insignificant Iterations
# Cost: 119523.5078125
# Iteration 105/1500 with 0 Insignificant Iterations
# Cost: 118122.2265625
# Iteration 106/1500 with 0 Insignificant Iterations
# Cost: 116745.6875
# Iteration 107/1500 with 0 Insignificant Iterations
# Cost: 115393.640625
# Iteration 108/1500 with 0 Insignificant Iterations
# Cost: 114065.1796875
# Iteration 109/1500 with 0 Insignificant Iterations
# Cost: 112759.65625
# Iteration 110/1500 with 0 Insignificant Iterations
# Cost: 111476.953125
# Iteration 111/1500 with 0 Insignificant Iterations
# Cost: 110216.0703125
# Iteration 112/1500 with 0 Insignificant Iterations
# Cost: 108976.875
# Iteration 113/1500 with 0 Insignificant Iterations
# Cost: 107758.4609375
# Iteration 114/1500 with 0 Insignificant Iterations
# Cost: 106560.84375
# Iteration 115/1500 with 0 Insignificant Iterations
# Cost: 105382.96875
# Iteration 116/1500 with 0 Insignificant Iterations
# Cost: 104224.9140625
# Iteration 117/1500 with 0 Insignificant Iterations
# Cost: 103086.015625
# Iteration 118/1500 with 0 Insignificant Iterations
# Cost: 101965.640625
# Iteration 119/1500 with 0 Insignificant Iterations
# Cost: 100863.6484375
# Iteration 120/1500 with 0 Insignificant Iterations
# Cost: 99779.921875
# Iteration 121/1500 with 0 Insignificant Iterations
# Cost: 98713.453125
# Iteration 122/1500 with 0 Insignificant Iterations
# Cost: 97664.1328125
# Iteration 123/1500 with 0 Insignificant Iterations
# Cost: 96631.7421875
# Iteration 124/1500 with 0 Insignificant Iterations
# Cost: 95615.3828125
# Iteration 125/1500 with 0 Insignificant Iterations
# Cost: 94615.484375
# Iteration 126/1500 with 0 Insignificant Iterations
# Cost: 93631.125
# Iteration 127/1500 with 0 Insignificant Iterations
# Cost: 92662.015625
# Iteration 128/1500 with 0 Insignificant Iterations
# Cost: 91708.25
# Iteration 129/1500 with 0 Insignificant Iterations
# Cost: 90769.078125
# Iteration 130/1500 with 0 Insignificant Iterations
# Cost: 89844.3359375
# Iteration 131/1500 with 0 Insignificant Iterations
# Cost: 88933.9296875
# Iteration 132/1500 with 0 Insignificant Iterations
# Cost: 88037.3203125
# Iteration 133/1500 with 0 Insignificant Iterations
# Cost: 87153.890625
# Iteration 134/1500 with 0 Insignificant Iterations
# Cost: 86283.8984375
# Iteration 135/1500 with 0 Insignificant Iterations
# Cost: 85427.1796875
# Iteration 136/1500 with 0 Insignificant Iterations
# Cost: 84582.9375
# Iteration 137/1500 with 0 Insignificant Iterations
# Cost: 83751.3046875
# Iteration 138/1500 with 0 Insignificant Iterations
# Cost: 82931.828125
# Iteration 139/1500 with 0 Insignificant Iterations
# Cost: 82124.5390625
# Iteration 140/1500 with 0 Insignificant Iterations
# Cost: 81328.71875
# Iteration 141/1500 with 0 Insignificant Iterations
# Cost: 80544.46875
# Iteration 142/1500 with 0 Insignificant Iterations
# Cost: 79771.8125
# Iteration 143/1500 with 0 Insignificant Iterations
# Cost: 79009.9140625
# Iteration 144/1500 with 0 Insignificant Iterations
# Cost: 78258.8828125
# Iteration 145/1500 with 0 Insignificant Iterations
# Cost: 77518.7890625
# Iteration 146/1500 with 0 Insignificant Iterations
# Cost: 76788.9453125
# Iteration 147/1500 with 0 Insignificant Iterations
# Cost: 76069.359375
# Iteration 148/1500 with 0 Insignificant Iterations
# Cost: 75359.765625
# Iteration 149/1500 with 0 Insignificant Iterations
# Cost: 74660.1328125
# Iteration 150/1500 with 0 Insignificant Iterations
# Cost: 73970.1484375
# Iteration 151/1500 with 0 Insignificant Iterations
# Cost: 73289.5703125
# Iteration 152/1500 with 0 Insignificant Iterations
# Cost: 72618.4921875
# Iteration 153/1500 with 0 Insignificant Iterations
# Cost: 71956.4453125
# Iteration 154/1500 with 0 Insignificant Iterations
# Cost: 71303.1875
# Iteration 155/1500 with 0 Insignificant Iterations
# Cost: 70658.8984375
# Iteration 156/1500 with 0 Insignificant Iterations
# Cost: 70023.1953125
# Iteration 157/1500 with 0 Insignificant Iterations
# Cost: 69396.25
# Iteration 158/1500 with 0 Insignificant Iterations
# Cost: 68777.1796875
# Iteration 159/1500 with 0 Insignificant Iterations
# Cost: 68166.515625
# Iteration 160/1500 with 0 Insignificant Iterations
# Cost: 67563.9921875
# Iteration 161/1500 with 0 Insignificant Iterations
# Cost: 66969.2578125
# Iteration 162/1500 with 0 Insignificant Iterations
# Cost: 66382.1328125
# Iteration 163/1500 with 0 Insignificant Iterations
# Cost: 65802.8671875
# Iteration 164/1500 with 0 Insignificant Iterations
# Cost: 65230.90234375
# Iteration 165/1500 with 0 Insignificant Iterations
# Cost: 64666.19140625
# Iteration 166/1500 with 0 Insignificant Iterations
# Cost: 64108.59765625
# Iteration 167/1500 with 0 Insignificant Iterations
# Cost: 63558.26171875
# Iteration 168/1500 with 0 Insignificant Iterations
# Cost: 63014.89453125
# Iteration 169/1500 with 0 Insignificant Iterations
# Cost: 62478.375
# Iteration 170/1500 with 0 Insignificant Iterations
# Cost: 61948.5078125
# Iteration 171/1500 with 0 Insignificant Iterations
# Cost: 61425.1015625
# Iteration 172/1500 with 0 Insignificant Iterations
# Cost: 60908.33203125
# Iteration 173/1500 with 0 Insignificant Iterations
# Cost: 60397.95703125
# Iteration 174/1500 with 0 Insignificant Iterations
# Cost: 59893.77734375
# Iteration 175/1500 with 0 Insignificant Iterations
# Cost: 59395.82421875
# Iteration 176/1500 with 0 Insignificant Iterations
# Cost: 58903.72265625
# Iteration 177/1500 with 0 Insignificant Iterations
# Cost: 58417.72265625
# Iteration 178/1500 with 0 Insignificant Iterations
# Cost: 57937.625
# Iteration 179/1500 with 0 Insignificant Iterations
# Cost: 57463.1875
# Iteration 180/1500 with 0 Insignificant Iterations
# Cost: 56994.50390625
# Iteration 181/1500 with 0 Insignificant Iterations
# Cost: 56531.296875
# Iteration 182/1500 with 0 Insignificant Iterations
# Cost: 56073.65234375
# Iteration 183/1500 with 0 Insignificant Iterations
# Cost: 55621.265625
# Iteration 184/1500 with 0 Insignificant Iterations
# Cost: 55174.3046875
# Iteration 185/1500 with 0 Insignificant Iterations
# Cost: 54732.26953125
# Iteration 186/1500 with 0 Insignificant Iterations
# Cost: 54295.61328125
# Iteration 187/1500 with 0 Insignificant Iterations
# Cost: 53863.8359375
# Iteration 188/1500 with 0 Insignificant Iterations
# Cost: 53437.3125
# Iteration 189/1500 with 0 Insignificant Iterations
# Cost: 53015.44921875
# Iteration 190/1500 with 0 Insignificant Iterations
# Cost: 52598.33203125
# Iteration 191/1500 with 0 Insignificant Iterations
# Cost: 52186.12109375
# Iteration 192/1500 with 0 Insignificant Iterations
# Cost: 51778.3671875
# Iteration 193/1500 with 0 Insignificant Iterations
# Cost: 51375.36328125
# Iteration 194/1500 with 0 Insignificant Iterations
# Cost: 50976.765625
# Iteration 195/1500 with 0 Insignificant Iterations
# Cost: 50582.640625
# Iteration 196/1500 with 0 Insignificant Iterations
# Cost: 50192.875
# Iteration 197/1500 with 0 Insignificant Iterations
# Cost: 49807.34765625
# Iteration 198/1500 with 0 Insignificant Iterations
# Cost: 49426.22265625
# Iteration 199/1500 with 0 Insignificant Iterations
# Cost: 49049.01953125
# Iteration 200/1500 with 0 Insignificant Iterations
# Cost: 48676.1328125
# Iteration 201/1500 with 0 Insignificant Iterations
# Cost: 48307.21875
# Iteration 202/1500 with 0 Insignificant Iterations
# Cost: 47942.09375
# Iteration 203/1500 with 0 Insignificant Iterations
# Cost: 47581.0546875
# Iteration 204/1500 with 0 Insignificant Iterations
# Cost: 47223.96484375
# Iteration 205/1500 with 0 Insignificant Iterations
# Cost: 46870.66015625
# Iteration 206/1500 with 0 Insignificant Iterations
# Cost: 46521.00390625
# Iteration 207/1500 with 0 Insignificant Iterations
# Cost: 46175.08203125
# Iteration 208/1500 with 0 Insignificant Iterations
# Cost: 45832.76953125
# Iteration 209/1500 with 0 Insignificant Iterations
# Cost: 45494.125
# Iteration 210/1500 with 0 Insignificant Iterations
# Cost: 45158.90234375
# Iteration 211/1500 with 0 Insignificant Iterations
# Cost: 44827.09375
# Iteration 212/1500 with 0 Insignificant Iterations
# Cost: 44498.8984375
# Iteration 213/1500 with 0 Insignificant Iterations
# Cost: 44174.0
# Iteration 214/1500 with 0 Insignificant Iterations
# Cost: 43852.37109375
# Iteration 215/1500 with 0 Insignificant Iterations
# Cost: 43534.19921875
# Iteration 216/1500 with 0 Insignificant Iterations
# Cost: 43219.03125
# Iteration 217/1500 with 0 Insignificant Iterations
# Cost: 42907.21484375
# Iteration 218/1500 with 0 Insignificant Iterations
# Cost: 42598.45703125
# Iteration 219/1500 with 0 Insignificant Iterations
# Cost: 42292.79296875
# Iteration 220/1500 with 0 Insignificant Iterations
# Cost: 41990.19921875
# Iteration 221/1500 with 0 Insignificant Iterations
# Cost: 41690.640625
# Iteration 222/1500 with 0 Insignificant Iterations
# Cost: 41394.07421875
# Iteration 223/1500 with 0 Insignificant Iterations
# Cost: 41100.41015625
# Iteration 224/1500 with 0 Insignificant Iterations
# Cost: 40809.671875
# Iteration 225/1500 with 0 Insignificant Iterations
# Cost: 40521.703125
# Iteration 226/1500 with 0 Insignificant Iterations
# Cost: 40236.53125
# Iteration 227/1500 with 0 Insignificant Iterations
# Cost: 39954.2265625
# Iteration 228/1500 with 0 Insignificant Iterations
# Cost: 39674.62109375
# Iteration 229/1500 with 0 Insignificant Iterations
# Cost: 39397.6796875
# Iteration 230/1500 with 0 Insignificant Iterations
# Cost: 39123.3828125
# Iteration 231/1500 with 0 Insignificant Iterations
# Cost: 38851.64453125
# Iteration 232/1500 with 0 Insignificant Iterations
# Cost: 38582.67578125
# Iteration 233/1500 with 0 Insignificant Iterations
# Cost: 38316.1171875
# Iteration 234/1500 with 0 Insignificant Iterations
# Cost: 38052.23046875
# Iteration 235/1500 with 0 Insignificant Iterations
# Cost: 37790.73828125
# Iteration 236/1500 with 0 Insignificant Iterations
# Cost: 37531.7265625
# Iteration 237/1500 with 0 Insignificant Iterations
# Cost: 37275.14453125
# Iteration 238/1500 with 0 Insignificant Iterations
# Cost: 37020.86328125
# Iteration 239/1500 with 0 Insignificant Iterations
# Cost: 36768.96484375
# Iteration 240/1500 with 0 Insignificant Iterations
# Cost: 36519.41796875
# Iteration 241/1500 with 0 Insignificant Iterations
# Cost: 36272.21875
# Iteration 242/1500 with 0 Insignificant Iterations
# Cost: 36027.28125
# Iteration 243/1500 with 0 Insignificant Iterations
# Cost: 35784.5625
# Iteration 244/1500 with 0 Insignificant Iterations
# Cost: 35544.078125
# Iteration 245/1500 with 0 Insignificant Iterations
# Cost: 35305.64453125
# Iteration 246/1500 with 0 Insignificant Iterations
# Cost: 35069.53125
# Iteration 247/1500 with 0 Insignificant Iterations
# Cost: 34835.5390625
# Iteration 248/1500 with 0 Insignificant Iterations
# Cost: 34603.609375
# Iteration 249/1500 with 0 Insignificant Iterations
# Cost: 34373.67578125
# Iteration 250/1500 with 0 Insignificant Iterations
# Cost: 34145.8671875
# Iteration 251/1500 with 0 Insignificant Iterations
# Cost: 33920.0625
# Iteration 252/1500 with 0 Insignificant Iterations
# Cost: 33696.3046875
# Iteration 253/1500 with 0 Insignificant Iterations
# Cost: 33474.484375
# Iteration 254/1500 with 0 Insignificant Iterations
# Cost: 33254.625
# Iteration 255/1500 with 0 Insignificant Iterations
# Cost: 33036.69140625
# Iteration 256/1500 with 0 Insignificant Iterations
# Cost: 32820.67578125
# Iteration 257/1500 with 0 Insignificant Iterations
# Cost: 32606.544921875
# Iteration 258/1500 with 0 Insignificant Iterations
# Cost: 32394.32421875
# Iteration 259/1500 with 0 Insignificant Iterations
# Cost: 32183.9375
# Iteration 260/1500 with 0 Insignificant Iterations
# Cost: 31975.265625
# Iteration 261/1500 with 0 Insignificant Iterations
# Cost: 31768.43359375
# Iteration 262/1500 with 0 Insignificant Iterations
# Cost: 31563.35546875
# Iteration 263/1500 with 0 Insignificant Iterations
# Cost: 31360.0859375
# Iteration 264/1500 with 0 Insignificant Iterations
# Cost: 31158.5
# Iteration 265/1500 with 0 Insignificant Iterations
# Cost: 30958.642578125
# Iteration 266/1500 with 0 Insignificant Iterations
# Cost: 30760.41015625
# Iteration 267/1500 with 0 Insignificant Iterations
# Cost: 30563.93359375
# Iteration 268/1500 with 0 Insignificant Iterations
# Cost: 30369.0625
# Iteration 269/1500 with 0 Insignificant Iterations
# Cost: 30175.91015625
# Iteration 270/1500 with 0 Insignificant Iterations
# Cost: 29984.322265625
# Iteration 271/1500 with 0 Insignificant Iterations
# Cost: 29794.33984375
# Iteration 272/1500 with 0 Insignificant Iterations
# Cost: 29605.921875
# Iteration 273/1500 with 0 Insignificant Iterations
# Cost: 29418.96484375
# Iteration 274/1500 with 0 Insignificant Iterations
# Cost: 29233.71484375
# Iteration 275/1500 with 0 Insignificant Iterations
# Cost: 29049.912109375
# Iteration 276/1500 with 0 Insignificant Iterations
# Cost: 28867.65234375
# Iteration 277/1500 with 0 Insignificant Iterations
# Cost: 28686.85546875
# Iteration 278/1500 with 0 Insignificant Iterations
# Cost: 28507.564453125
# Iteration 279/1500 with 0 Insignificant Iterations
# Cost: 28329.677734375
# Iteration 280/1500 with 0 Insignificant Iterations
# Cost: 28153.32421875
# Iteration 281/1500 with 0 Insignificant Iterations
# Cost: 27978.265625
# Iteration 282/1500 with 0 Insignificant Iterations
# Cost: 27804.763671875
# Iteration 283/1500 with 0 Insignificant Iterations
# Cost: 27632.626953125
# Iteration 284/1500 with 0 Insignificant Iterations
# Cost: 27461.76171875
# Iteration 285/1500 with 0 Insignificant Iterations
# Cost: 27292.4140625
# Iteration 286/1500 with 0 Insignificant Iterations
# Cost: 27124.306640625
# Iteration 287/1500 with 0 Insignificant Iterations
# Cost: 26957.595703125
# Iteration 288/1500 with 0 Insignificant Iterations
# Cost: 26792.19140625
# Iteration 289/1500 with 0 Insignificant Iterations
# Cost: 26628.09375
# Iteration 290/1500 with 0 Insignificant Iterations
# Cost: 26465.376953125
# Iteration 291/1500 with 0 Insignificant Iterations
# Cost: 26303.828125
# Iteration 292/1500 with 0 Insignificant Iterations
# Cost: 26143.521484375
# Iteration 293/1500 with 0 Insignificant Iterations
# Cost: 25984.65234375
# Iteration 294/1500 with 0 Insignificant Iterations
# Cost: 25826.888671875
# Iteration 295/1500 with 0 Insignificant Iterations
# Cost: 25670.373046875
# Iteration 296/1500 with 0 Insignificant Iterations
# Cost: 25515.033203125
# Iteration 297/1500 with 0 Insignificant Iterations
# Cost: 25360.953125
# Iteration 298/1500 with 0 Insignificant Iterations
# Cost: 25208.15234375
# Iteration 299/1500 with 0 Insignificant Iterations
# Cost: 25056.482421875
# Iteration 300/1500 with 0 Insignificant Iterations
# Cost: 24905.818359375
# Iteration 301/1500 with 0 Insignificant Iterations
# Cost: 24756.48828125
# Iteration 302/1500 with 0 Insignificant Iterations
# Cost: 24608.201171875
# Iteration 303/1500 with 0 Insignificant Iterations
# Cost: 24461.087890625
# Iteration 304/1500 with 0 Insignificant Iterations
# Cost: 24315.197265625
# Iteration 305/1500 with 0 Insignificant Iterations
# Cost: 24170.255859375
# Iteration 306/1500 with 0 Insignificant Iterations
# Cost: 24026.572265625
# Iteration 307/1500 with 0 Insignificant Iterations
# Cost: 23883.884765625
# Iteration 308/1500 with 0 Insignificant Iterations
# Cost: 23742.28125
# Iteration 309/1500 with 0 Insignificant Iterations
# Cost: 23601.734375
# Iteration 310/1500 with 0 Insignificant Iterations
# Cost: 23462.244140625
# Iteration 311/1500 with 0 Insignificant Iterations
# Cost: 23323.869140625
# Iteration 312/1500 with 0 Insignificant Iterations
# Cost: 23186.529296875
# Iteration 313/1500 with 0 Insignificant Iterations
# Cost: 23050.140625
# Iteration 314/1500 with 0 Insignificant Iterations
# Cost: 22914.80078125
# Iteration 315/1500 with 0 Insignificant Iterations
# Cost: 22780.529296875
# Iteration 316/1500 with 0 Insignificant Iterations
# Cost: 22647.1796875
# Iteration 317/1500 with 0 Insignificant Iterations
# Cost: 22514.86328125
# Iteration 318/1500 with 0 Insignificant Iterations
# Cost: 22383.51171875
# Iteration 319/1500 with 0 Insignificant Iterations
# Cost: 22253.126953125
# Iteration 320/1500 with 0 Insignificant Iterations
# Cost: 22123.7578125
# Iteration 321/1500 with 0 Insignificant Iterations
# Cost: 21995.248046875
# Iteration 322/1500 with 0 Insignificant Iterations
# Cost: 21867.765625
# Iteration 323/1500 with 0 Insignificant Iterations
# Cost: 21741.162109375
# Iteration 324/1500 with 0 Insignificant Iterations
# Cost: 21615.4296875
# Iteration 325/1500 with 0 Insignificant Iterations
# Cost: 21490.759765625
# Iteration 326/1500 with 0 Insignificant Iterations
# Cost: 21366.923828125
# Iteration 327/1500 with 0 Insignificant Iterations
# Cost: 21244.033203125
# Iteration 328/1500 with 0 Insignificant Iterations
# Cost: 21121.92578125
# Iteration 329/1500 with 0 Insignificant Iterations
# Cost: 21000.83984375
# Iteration 330/1500 with 0 Insignificant Iterations
# Cost: 20880.53515625
# Iteration 331/1500 with 0 Insignificant Iterations
# Cost: 20761.171875
# Iteration 332/1500 with 0 Insignificant Iterations
# Cost: 20642.615234375
# Iteration 333/1500 with 0 Insignificant Iterations
# Cost: 20524.943359375
# Iteration 334/1500 with 0 Insignificant Iterations
# Cost: 20408.125
# Iteration 335/1500 with 0 Insignificant Iterations
# Cost: 20292.12890625
# Iteration 336/1500 with 0 Insignificant Iterations
# Cost: 20176.9765625
# Iteration 337/1500 with 0 Insignificant Iterations
# Cost: 20062.623046875
# Iteration 338/1500 with 0 Insignificant Iterations
# Cost: 19949.091796875
# Iteration 339/1500 with 0 Insignificant Iterations
# Cost: 19836.392578125
# Iteration 340/1500 with 0 Insignificant Iterations
# Cost: 19724.49609375
# Iteration 341/1500 with 0 Insignificant Iterations
# Cost: 19613.33984375
# Iteration 342/1500 with 0 Insignificant Iterations
# Cost: 19503.033203125
# Iteration 343/1500 with 0 Insignificant Iterations
# Cost: 19393.478515625
# Iteration 344/1500 with 0 Insignificant Iterations
# Cost: 19284.70703125
# Iteration 345/1500 with 0 Insignificant Iterations
# Cost: 19176.720703125
# Iteration 346/1500 with 0 Insignificant Iterations
# Cost: 19069.5078125
# Iteration 347/1500 with 0 Insignificant Iterations
# Cost: 18963.013671875
# Iteration 348/1500 with 0 Insignificant Iterations
# Cost: 18857.3046875
# Iteration 349/1500 with 0 Insignificant Iterations
# Cost: 18752.279296875
# Iteration 350/1500 with 0 Insignificant Iterations
# Cost: 18648.0390625
# Iteration 351/1500 with 0 Insignificant Iterations
# Cost: 18544.525390625
# Iteration 352/1500 with 0 Insignificant Iterations
# Cost: 18441.69921875
# Iteration 353/1500 with 0 Insignificant Iterations
# Cost: 18339.671875
# Iteration 354/1500 with 0 Insignificant Iterations
# Cost: 18238.310546875
# Iteration 355/1500 with 0 Insignificant Iterations
# Cost: 18137.603515625
# Iteration 356/1500 with 0 Insignificant Iterations
# Cost: 18037.64453125
# Iteration 357/1500 with 0 Insignificant Iterations
# Cost: 17938.41015625
# Iteration 358/1500 with 0 Insignificant Iterations
# Cost: 17839.771484375
# Iteration 359/1500 with 0 Insignificant Iterations
# Cost: 17741.91015625
# Iteration 360/1500 with 0 Insignificant Iterations
# Cost: 17644.716796875
# Iteration 361/1500 with 0 Insignificant Iterations
# Cost: 17548.109375
# Iteration 362/1500 with 0 Insignificant Iterations
# Cost: 17452.271484375
# Iteration 363/1500 with 0 Insignificant Iterations
# Cost: 17357.04296875
# Iteration 364/1500 with 0 Insignificant Iterations
# Cost: 17262.451171875
# Iteration 365/1500 with 0 Insignificant Iterations
# Cost: 17168.529296875
# Iteration 366/1500 with 0 Insignificant Iterations
# Cost: 17075.294921875
# Iteration 367/1500 with 0 Insignificant Iterations
# Cost: 16982.673828125
# Iteration 368/1500 with 0 Insignificant Iterations
# Cost: 16890.609375
# Iteration 369/1500 with 0 Insignificant Iterations
# Cost: 16799.296875
# Iteration 370/1500 with 0 Insignificant Iterations
# Cost: 16708.54296875
# Iteration 371/1500 with 0 Insignificant Iterations
# Cost: 16618.400390625
# Iteration 372/1500 with 0 Insignificant Iterations
# Cost: 16528.896484375
# Iteration 373/1500 with 0 Insignificant Iterations
# Cost: 16439.982421875
# Iteration 374/1500 with 0 Insignificant Iterations
# Cost: 16351.7470703125
# Iteration 375/1500 with 0 Insignificant Iterations
# Cost: 16264.015625
# Iteration 376/1500 with 0 Insignificant Iterations
# Cost: 16176.91015625
# Iteration 377/1500 with 0 Insignificant Iterations
# Cost: 16090.439453125
# Iteration 378/1500 with 0 Insignificant Iterations
# Cost: 16004.4765625
# Iteration 379/1500 with 0 Insignificant Iterations
# Cost: 15919.166015625
# Iteration 380/1500 with 0 Insignificant Iterations
# Cost: 15834.39453125
# Iteration 381/1500 with 0 Insignificant Iterations
# Cost: 15750.181640625
# Iteration 382/1500 with 0 Insignificant Iterations
# Cost: 15666.5654296875
# Iteration 383/1500 with 0 Insignificant Iterations
# Cost: 15583.4765625
# Iteration 384/1500 with 0 Insignificant Iterations
# Cost: 15500.9921875
# Iteration 385/1500 with 0 Insignificant Iterations
# Cost: 15419.0595703125
# Iteration 386/1500 with 0 Insignificant Iterations
# Cost: 15337.67578125
# Iteration 387/1500 with 0 Insignificant Iterations
# Cost: 15256.822265625
# Iteration 388/1500 with 0 Insignificant Iterations
# Cost: 15176.4853515625
# Iteration 389/1500 with 0 Insignificant Iterations
# Cost: 15096.751953125
# Iteration 390/1500 with 0 Insignificant Iterations
# Cost: 15017.4775390625
# Iteration 391/1500 with 0 Insignificant Iterations
# Cost: 14938.7734375
# Iteration 392/1500 with 0 Insignificant Iterations
# Cost: 14860.5927734375
# Iteration 393/1500 with 0 Insignificant Iterations
# Cost: 14782.95703125
# Iteration 394/1500 with 0 Insignificant Iterations
# Cost: 14705.7607421875
# Iteration 395/1500 with 0 Insignificant Iterations
# Cost: 14629.173828125
# Iteration 396/1500 with 0 Insignificant Iterations
# Cost: 14553.0810546875
# Iteration 397/1500 with 0 Insignificant Iterations
# Cost: 14477.4755859375
# Iteration 398/1500 with 0 Insignificant Iterations
# Cost: 14402.333984375
# Iteration 399/1500 with 0 Insignificant Iterations
# Cost: 14327.7041015625
# Iteration 400/1500 with 0 Insignificant Iterations
# Cost: 14253.5771484375
# Iteration 401/1500 with 0 Insignificant Iterations
# Cost: 14179.97265625
# Iteration 402/1500 with 0 Insignificant Iterations
# Cost: 14106.8583984375
# Iteration 403/1500 with 0 Insignificant Iterations
# Cost: 14034.1845703125
# Iteration 404/1500 with 0 Insignificant Iterations
# Cost: 13961.9921875
# Iteration 405/1500 with 0 Insignificant Iterations
# Cost: 13890.2958984375
# Iteration 406/1500 with 0 Insignificant Iterations
# Cost: 13819.052734375
# Iteration 407/1500 with 0 Insignificant Iterations
# Cost: 13748.3076171875
# Iteration 408/1500 with 0 Insignificant Iterations
# Cost: 13678.0439453125
# Iteration 409/1500 with 0 Insignificant Iterations
# Cost: 13608.197265625
# Iteration 410/1500 with 0 Insignificant Iterations
# Cost: 13538.8544921875
# Iteration 411/1500 with 0 Insignificant Iterations
# Cost: 13469.927734375
# Iteration 412/1500 with 0 Insignificant Iterations
# Cost: 13401.443359375
# Iteration 413/1500 with 0 Insignificant Iterations
# Cost: 13333.439453125
# Iteration 414/1500 with 0 Insignificant Iterations
# Cost: 13265.88671875
# Iteration 415/1500 with 0 Insignificant Iterations
# Cost: 13198.7783203125
# Iteration 416/1500 with 0 Insignificant Iterations
# Cost: 13132.0712890625
# Iteration 417/1500 with 0 Insignificant Iterations
# Cost: 13065.8466796875
# Iteration 418/1500 with 0 Insignificant Iterations
# Cost: 13000.0185546875
# Iteration 419/1500 with 0 Insignificant Iterations
# Cost: 12934.6484375
# Iteration 420/1500 with 0 Insignificant Iterations
# Cost: 12869.6884765625
# Iteration 421/1500 with 0 Insignificant Iterations
# Cost: 12805.12890625
# Iteration 422/1500 with 0 Insignificant Iterations
# Cost: 12741.0244140625
# Iteration 423/1500 with 0 Insignificant Iterations
# Cost: 12677.3583984375
# Iteration 424/1500 with 0 Insignificant Iterations
# Cost: 12614.04296875
# Iteration 425/1500 with 0 Insignificant Iterations
# Cost: 12551.1865234375
# Iteration 426/1500 with 0 Insignificant Iterations
# Cost: 12488.7216796875
# Iteration 427/1500 with 0 Insignificant Iterations
# Cost: 12426.6767578125
# Iteration 428/1500 with 0 Insignificant Iterations
# Cost: 12365.0166015625
# Iteration 429/1500 with 0 Insignificant Iterations
# Cost: 12303.7490234375
# Iteration 430/1500 with 0 Insignificant Iterations
# Cost: 12242.8994140625
# Iteration 431/1500 with 0 Insignificant Iterations
# Cost: 12182.458984375
# Iteration 432/1500 with 0 Insignificant Iterations
# Cost: 12122.3720703125
# Iteration 433/1500 with 0 Insignificant Iterations
# Cost: 12062.703125
# Iteration 434/1500 with 0 Insignificant Iterations
# Cost: 12003.4130859375
# Iteration 435/1500 with 0 Insignificant Iterations
# Cost: 11944.501953125
# Iteration 436/1500 with 0 Insignificant Iterations
# Cost: 11885.9853515625
# Iteration 437/1500 with 0 Insignificant Iterations
# Cost: 11827.796875
# Iteration 438/1500 with 0 Insignificant Iterations
# Cost: 11770.0126953125
# Iteration 439/1500 with 0 Insignificant Iterations
# Cost: 11712.634765625
# Iteration 440/1500 with 0 Insignificant Iterations
# Cost: 11655.5830078125
# Iteration 441/1500 with 0 Insignificant Iterations
# Cost: 11598.90625
# Iteration 442/1500 with 0 Insignificant Iterations
# Cost: 11542.6142578125
# Iteration 443/1500 with 0 Insignificant Iterations
# Cost: 11486.6533203125
# Iteration 444/1500 with 0 Insignificant Iterations
# Cost: 11431.083984375
# Iteration 445/1500 with 0 Insignificant Iterations
# Cost: 11375.8310546875
# Iteration 446/1500 with 0 Insignificant Iterations
# Cost: 11320.962890625
# Iteration 447/1500 with 0 Insignificant Iterations
# Cost: 11266.482421875
# Iteration 448/1500 with 0 Insignificant Iterations
# Cost: 11212.296875
# Iteration 449/1500 with 0 Insignificant Iterations
# Cost: 11158.44921875
# Iteration 450/1500 with 0 Insignificant Iterations
# Cost: 11104.9765625
# Iteration 451/1500 with 0 Insignificant Iterations
# Cost: 11051.8388671875
# Iteration 452/1500 with 0 Insignificant Iterations
# Cost: 10999.0263671875
# Iteration 453/1500 with 0 Insignificant Iterations
# Cost: 10946.5625
# Iteration 454/1500 with 0 Insignificant Iterations
# Cost: 10894.4375
# Iteration 455/1500 with 0 Insignificant Iterations
# Cost: 10842.6572265625
# Iteration 456/1500 with 0 Insignificant Iterations
# Cost: 10791.197265625
# Iteration 457/1500 with 0 Insignificant Iterations
# Cost: 10740.078125
# Iteration 458/1500 with 0 Insignificant Iterations
# Cost: 10689.2763671875
# Iteration 459/1500 with 0 Insignificant Iterations
# Cost: 10638.779296875
# Iteration 460/1500 with 0 Insignificant Iterations
# Cost: 10588.6064453125
# Iteration 461/1500 with 0 Insignificant Iterations
# Cost: 10538.76953125
# Iteration 462/1500 with 0 Insignificant Iterations
# Cost: 10489.2314453125
# Iteration 463/1500 with 0 Insignificant Iterations
# Cost: 10440.0205078125
# Iteration 464/1500 with 0 Insignificant Iterations
# Cost: 10391.0849609375
# Iteration 465/1500 with 0 Insignificant Iterations
# Cost: 10342.5029296875
# Iteration 466/1500 with 0 Insignificant Iterations
# Cost: 10294.2509765625
# Iteration 467/1500 with 0 Insignificant Iterations
# Cost: 10246.2568359375
# Iteration 468/1500 with 0 Insignificant Iterations
# Cost: 10198.560546875
# Iteration 469/1500 with 0 Insignificant Iterations
# Cost: 10151.2158203125
# Iteration 470/1500 with 0 Insignificant Iterations
# Cost: 10104.1298828125
# Iteration 471/1500 with 0 Insignificant Iterations
# Cost: 10057.37109375
# Iteration 472/1500 with 0 Insignificant Iterations
# Cost: 10010.8955078125
# Iteration 473/1500 with 0 Insignificant Iterations
# Cost: 9964.7060546875
# Iteration 474/1500 with 0 Insignificant Iterations
# Cost: 9918.802734375
# Iteration 475/1500 with 0 Insignificant Iterations
# Cost: 9873.2001953125
# Iteration 476/1500 with 0 Insignificant Iterations
# Cost: 9827.8896484375
# Iteration 477/1500 with 0 Insignificant Iterations
# Cost: 9782.8603515625
# Iteration 478/1500 with 0 Insignificant Iterations
# Cost: 9738.1005859375
# Iteration 479/1500 with 0 Insignificant Iterations
# Cost: 9693.626953125
# Iteration 480/1500 with 0 Insignificant Iterations
# Cost: 9649.44140625
# Iteration 481/1500 with 0 Insignificant Iterations
# Cost: 9605.54296875
# Iteration 482/1500 with 0 Insignificant Iterations
# Cost: 9561.8916015625
# Iteration 483/1500 with 0 Insignificant Iterations
# Cost: 9518.5400390625
# Iteration 484/1500 with 0 Insignificant Iterations
# Cost: 9475.4482421875
# Iteration 485/1500 with 0 Insignificant Iterations
# Cost: 9432.630859375
# Iteration 486/1500 with 0 Insignificant Iterations
# Cost: 9390.0732421875
# Iteration 487/1500 with 0 Insignificant Iterations
# Cost: 9347.8203125
# Iteration 488/1500 with 0 Insignificant Iterations
# Cost: 9305.763671875
# Iteration 489/1500 with 0 Insignificant Iterations
# Cost: 9264.013671875
# Iteration 490/1500 with 0 Insignificant Iterations
# Cost: 9222.5068359375
# Iteration 491/1500 with 0 Insignificant Iterations
# Cost: 9181.287109375
# Iteration 492/1500 with 0 Insignificant Iterations
# Cost: 9140.3037109375
# Iteration 493/1500 with 0 Insignificant Iterations
# Cost: 9099.599609375
# Iteration 494/1500 with 0 Insignificant Iterations
# Cost: 9059.1328125
# Iteration 495/1500 with 0 Insignificant Iterations
# Cost: 9018.908203125
# Iteration 496/1500 with 0 Insignificant Iterations
# Cost: 8978.94140625
# Iteration 497/1500 with 0 Insignificant Iterations
# Cost: 8939.2177734375
# Iteration 498/1500 with 0 Insignificant Iterations
# Cost: 8899.7470703125
# Iteration 499/1500 with 0 Insignificant Iterations
# Cost: 8860.5087890625
# Iteration 500/1500 with 0 Insignificant Iterations
# Cost: 8821.544921875
# Iteration 501/1500 with 0 Insignificant Iterations
# Cost: 8782.8095703125
# Iteration 502/1500 with 0 Insignificant Iterations
# Cost: 8744.3203125
# Iteration 503/1500 with 0 Insignificant Iterations
# Cost: 8706.03125
# Iteration 504/1500 with 0 Insignificant Iterations
# Cost: 8668.0458984375
# Iteration 505/1500 with 0 Insignificant Iterations
# Cost: 8630.24609375
# Iteration 506/1500 with 0 Insignificant Iterations
# Cost: 8592.685546875
# Iteration 507/1500 with 0 Insignificant Iterations
# Cost: 8555.3701171875
# Iteration 508/1500 with 0 Insignificant Iterations
# Cost: 8518.296875
# Iteration 509/1500 with 0 Insignificant Iterations
# Cost: 8481.4326171875
# Iteration 510/1500 with 0 Insignificant Iterations
# Cost: 8444.791015625
# Iteration 511/1500 with 0 Insignificant Iterations
# Cost: 8408.404296875
# Iteration 512/1500 with 0 Insignificant Iterations
# Cost: 8372.20703125
# Iteration 513/1500 with 0 Insignificant Iterations
# Cost: 8336.23046875
# Iteration 514/1500 with 0 Insignificant Iterations
# Cost: 8300.53515625
# Iteration 515/1500 with 0 Insignificant Iterations
# Cost: 8265.009765625
# Iteration 516/1500 with 0 Insignificant Iterations
# Cost: 8229.7041015625
# Iteration 517/1500 with 0 Insignificant Iterations
# Cost: 8194.62109375
# Iteration 518/1500 with 0 Insignificant Iterations
# Cost: 8159.76611328125
# Iteration 519/1500 with 0 Insignificant Iterations
# Cost: 8125.1123046875
# Iteration 520/1500 with 0 Insignificant Iterations
# Cost: 8090.68212890625
# Iteration 521/1500 with 0 Insignificant Iterations
# Cost: 8056.45556640625
# Iteration 522/1500 with 0 Insignificant Iterations
# Cost: 8022.42529296875
# Iteration 523/1500 with 0 Insignificant Iterations
# Cost: 7988.615234375
# Iteration 524/1500 with 0 Insignificant Iterations
# Cost: 7955.0078125
# Iteration 525/1500 with 0 Insignificant Iterations
# Cost: 7921.599609375
# Iteration 526/1500 with 0 Insignificant Iterations
# Cost: 7888.42578125
# Iteration 527/1500 with 0 Insignificant Iterations
# Cost: 7855.42919921875
# Iteration 528/1500 with 0 Insignificant Iterations
# Cost: 7822.66162109375
# Iteration 529/1500 with 0 Insignificant Iterations
# Cost: 7790.08984375
# Iteration 530/1500 with 0 Insignificant Iterations
# Cost: 7757.67578125
# Iteration 531/1500 with 0 Insignificant Iterations
# Cost: 7725.4912109375
# Iteration 532/1500 with 0 Insignificant Iterations
# Cost: 7693.49560546875
# Iteration 533/1500 with 0 Insignificant Iterations
# Cost: 7661.68212890625
# Iteration 534/1500 with 0 Insignificant Iterations
# Cost: 7630.072265625
# Iteration 535/1500 with 0 Insignificant Iterations
# Cost: 7598.65966796875
# Iteration 536/1500 with 0 Insignificant Iterations
# Cost: 7567.45166015625
# Iteration 537/1500 with 0 Insignificant Iterations
# Cost: 7536.40869140625
# Iteration 538/1500 with 0 Insignificant Iterations
# Cost: 7505.54931640625
# Iteration 539/1500 with 0 Insignificant Iterations
# Cost: 7474.892578125
# Iteration 540/1500 with 0 Insignificant Iterations
# Cost: 7444.43115234375
# Iteration 541/1500 with 0 Insignificant Iterations
# Cost: 7414.13916015625
# Iteration 542/1500 with 0 Insignificant Iterations
# Cost: 7384.01416015625
# Iteration 543/1500 with 0 Insignificant Iterations
# Cost: 7354.09033203125
# Iteration 544/1500 with 0 Insignificant Iterations
# Cost: 7324.34375
# Iteration 545/1500 with 0 Insignificant Iterations
# Cost: 7294.81103515625
# Iteration 546/1500 with 0 Insignificant Iterations
# Cost: 7265.384765625
# Iteration 547/1500 with 0 Insignificant Iterations
# Cost: 7236.18701171875
# Iteration 548/1500 with 0 Insignificant Iterations
# Cost: 7207.15869140625
# Iteration 549/1500 with 0 Insignificant Iterations
# Cost: 7178.2998046875
# Iteration 550/1500 with 0 Insignificant Iterations
# Cost: 7149.61279296875
# Iteration 551/1500 with 0 Insignificant Iterations
# Cost: 7121.1064453125
# Iteration 552/1500 with 0 Insignificant Iterations
# Cost: 7092.76025390625
# Iteration 553/1500 with 0 Insignificant Iterations
# Cost: 7064.59423828125
# Iteration 554/1500 with 0 Insignificant Iterations
# Cost: 7036.5888671875
# Iteration 555/1500 with 0 Insignificant Iterations
# Cost: 7008.7470703125
# Iteration 556/1500 with 0 Insignificant Iterations
# Cost: 6981.07568359375
# Iteration 557/1500 with 0 Insignificant Iterations
# Cost: 6953.578125
# Iteration 558/1500 with 0 Insignificant Iterations
# Cost: 6926.23046875
# Iteration 559/1500 with 0 Insignificant Iterations
# Cost: 6899.05224609375
# Iteration 560/1500 with 0 Insignificant Iterations
# Cost: 6872.052734375
# Iteration 561/1500 with 0 Insignificant Iterations
# Cost: 6845.171875
# Iteration 562/1500 with 0 Insignificant Iterations
# Cost: 6818.45556640625
# Iteration 563/1500 with 0 Insignificant Iterations
# Cost: 6791.93798828125
# Iteration 564/1500 with 0 Insignificant Iterations
# Cost: 6765.580078125
# Iteration 565/1500 with 0 Insignificant Iterations
# Cost: 6739.341796875
# Iteration 566/1500 with 0 Insignificant Iterations
# Cost: 6713.296875
# Iteration 567/1500 with 0 Insignificant Iterations
# Cost: 6687.35107421875
# Iteration 568/1500 with 0 Insignificant Iterations
# Cost: 6661.60205078125
# Iteration 569/1500 with 0 Insignificant Iterations
# Cost: 6635.990234375
# Iteration 570/1500 with 0 Insignificant Iterations
# Cost: 6610.53955078125
# Iteration 571/1500 with 0 Insignificant Iterations
# Cost: 6585.23974609375
# Iteration 572/1500 with 0 Insignificant Iterations
# Cost: 6560.068359375
# Iteration 573/1500 with 0 Insignificant Iterations
# Cost: 6535.0986328125
# Iteration 574/1500 with 0 Insignificant Iterations
# Cost: 6510.216796875
# Iteration 575/1500 with 0 Insignificant Iterations
# Cost: 6485.48095703125
# Iteration 576/1500 with 0 Insignificant Iterations
# Cost: 6460.94580078125
# Iteration 577/1500 with 0 Insignificant Iterations
# Cost: 6436.513671875
# Iteration 578/1500 with 0 Insignificant Iterations
# Cost: 6412.21923828125
# Iteration 579/1500 with 0 Insignificant Iterations
# Cost: 6388.08642578125
# Iteration 580/1500 with 0 Insignificant Iterations
# Cost: 6364.08203125
# Iteration 581/1500 with 0 Insignificant Iterations
# Cost: 6340.23681640625
# Iteration 582/1500 with 0 Insignificant Iterations
# Cost: 6316.51513671875
# Iteration 583/1500 with 0 Insignificant Iterations
# Cost: 6292.95703125
# Iteration 584/1500 with 0 Insignificant Iterations
# Cost: 6269.48095703125
# Iteration 585/1500 with 0 Insignificant Iterations
# Cost: 6246.17529296875
# Iteration 586/1500 with 0 Insignificant Iterations
# Cost: 6223.02490234375
# Iteration 587/1500 with 0 Insignificant Iterations
# Cost: 6199.9619140625
# Iteration 588/1500 with 0 Insignificant Iterations
# Cost: 6177.099609375
# Iteration 589/1500 with 0 Insignificant Iterations
# Cost: 6154.32861328125
# Iteration 590/1500 with 0 Insignificant Iterations
# Cost: 6131.6962890625
# Iteration 591/1500 with 0 Insignificant Iterations
# Cost: 6109.1767578125
# Iteration 592/1500 with 0 Insignificant Iterations
# Cost: 6086.8056640625
# Iteration 593/1500 with 0 Insignificant Iterations
# Cost: 6064.57275390625
# Iteration 594/1500 with 0 Insignificant Iterations
# Cost: 6042.4443359375
# Iteration 595/1500 with 0 Insignificant Iterations
# Cost: 6020.42138671875
# Iteration 596/1500 with 0 Insignificant Iterations
# Cost: 5998.5732421875
# Iteration 597/1500 with 0 Insignificant Iterations
# Cost: 5976.8681640625
# Iteration 598/1500 with 0 Insignificant Iterations
# Cost: 5955.24169921875
# Iteration 599/1500 with 0 Insignificant Iterations
# Cost: 5933.73681640625
# Iteration 600/1500 with 0 Insignificant Iterations
# Cost: 5912.37841796875
# Iteration 601/1500 with 0 Insignificant Iterations
# Cost: 5891.13232421875
# Iteration 602/1500 with 0 Insignificant Iterations
# Cost: 5870.0087890625
# Iteration 603/1500 with 0 Insignificant Iterations
# Cost: 5849.02392578125
# Iteration 604/1500 with 0 Insignificant Iterations
# Cost: 5828.13232421875
# Iteration 605/1500 with 0 Insignificant Iterations
# Cost: 5807.3505859375
# Iteration 606/1500 with 0 Insignificant Iterations
# Cost: 5786.72412109375
# Iteration 607/1500 with 0 Insignificant Iterations
# Cost: 5766.20263671875
# Iteration 608/1500 with 0 Insignificant Iterations
# Cost: 5745.78466796875
# Iteration 609/1500 with 0 Insignificant Iterations
# Cost: 5725.4873046875
# Iteration 610/1500 with 0 Insignificant Iterations
# Cost: 5705.3173828125
# Iteration 611/1500 with 0 Insignificant Iterations
# Cost: 5685.25
# Iteration 612/1500 with 0 Insignificant Iterations
# Cost: 5665.28857421875
# Iteration 613/1500 with 0 Insignificant Iterations
# Cost: 5645.4755859375
# Iteration 614/1500 with 0 Insignificant Iterations
# Cost: 5625.740234375
# Iteration 615/1500 with 0 Insignificant Iterations
# Cost: 5606.1171875
# Iteration 616/1500 with 0 Insignificant Iterations
# Cost: 5586.61279296875
# Iteration 617/1500 with 0 Insignificant Iterations
# Cost: 5567.21875
# Iteration 618/1500 with 0 Insignificant Iterations
# Cost: 5547.958984375
# Iteration 619/1500 with 0 Insignificant Iterations
# Cost: 5528.7822265625
# Iteration 620/1500 with 0 Insignificant Iterations
# Cost: 5509.70556640625
# Iteration 621/1500 with 0 Insignificant Iterations
# Cost: 5490.73046875
# Iteration 622/1500 with 0 Insignificant Iterations
# Cost: 5471.87060546875
# Iteration 623/1500 with 0 Insignificant Iterations
# Cost: 5453.13330078125
# Iteration 624/1500 with 0 Insignificant Iterations
# Cost: 5434.47802734375
# Iteration 625/1500 with 0 Insignificant Iterations
# Cost: 5415.9462890625
# Iteration 626/1500 with 0 Insignificant Iterations
# Cost: 5397.49169921875
# Iteration 627/1500 with 0 Insignificant Iterations
# Cost: 5379.1533203125
# Iteration 628/1500 with 0 Insignificant Iterations
# Cost: 5360.9208984375
# Iteration 629/1500 with 0 Insignificant Iterations
# Cost: 5342.79345703125
# Iteration 630/1500 with 0 Insignificant Iterations
# Cost: 5324.78125
# Iteration 631/1500 with 0 Insignificant Iterations
# Cost: 5306.81982421875
# Iteration 632/1500 with 0 Insignificant Iterations
# Cost: 5288.9677734375
# Iteration 633/1500 with 0 Insignificant Iterations
# Cost: 5271.2431640625
# Iteration 634/1500 with 0 Insignificant Iterations
# Cost: 5253.61376953125
# Iteration 635/1500 with 0 Insignificant Iterations
# Cost: 5236.06298828125
# Iteration 636/1500 with 0 Insignificant Iterations
# Cost: 5218.6142578125
# Iteration 637/1500 with 0 Insignificant Iterations
# Cost: 5201.2724609375
# Iteration 638/1500 with 0 Insignificant Iterations
# Cost: 5184.0166015625
# Iteration 639/1500 with 0 Insignificant Iterations
# Cost: 5166.83447265625
# Iteration 640/1500 with 0 Insignificant Iterations
# Cost: 5149.76806640625
# Iteration 641/1500 with 0 Insignificant Iterations
# Cost: 5132.83642578125
# Iteration 642/1500 with 0 Insignificant Iterations
# Cost: 5115.95263671875
# Iteration 643/1500 with 0 Insignificant Iterations
# Cost: 5099.1513671875
# Iteration 644/1500 with 0 Insignificant Iterations
# Cost: 5082.45068359375
# Iteration 645/1500 with 0 Insignificant Iterations
# Cost: 5065.83203125
# Iteration 646/1500 with 0 Insignificant Iterations
# Cost: 5049.30908203125
# Iteration 647/1500 with 0 Insignificant Iterations
# Cost: 5032.8828125
# Iteration 648/1500 with 0 Insignificant Iterations
# Cost: 5016.5556640625
# Iteration 649/1500 with 0 Insignificant Iterations
# Cost: 5000.30224609375
# Iteration 650/1500 with 0 Insignificant Iterations
# Cost: 4984.1220703125
# Iteration 651/1500 with 0 Insignificant Iterations
# Cost: 4968.029296875
# Iteration 652/1500 with 0 Insignificant Iterations
# Cost: 4952.04248046875
# Iteration 653/1500 with 0 Insignificant Iterations
# Cost: 4936.14990234375
# Iteration 654/1500 with 0 Insignificant Iterations
# Cost: 4920.33349609375
# Iteration 655/1500 with 0 Insignificant Iterations
# Cost: 4904.58056640625
# Iteration 656/1500 with 0 Insignificant Iterations
# Cost: 4888.9228515625
# Iteration 657/1500 with 0 Insignificant Iterations
# Cost: 4873.35009765625
# Iteration 658/1500 with 0 Insignificant Iterations
# Cost: 4857.87158203125
# Iteration 659/1500 with 0 Insignificant Iterations
# Cost: 4842.45556640625
# Iteration 660/1500 with 0 Insignificant Iterations
# Cost: 4827.146484375
# Iteration 661/1500 with 0 Insignificant Iterations
# Cost: 4811.90234375
# Iteration 662/1500 with 0 Insignificant Iterations
# Cost: 4796.73828125
# Iteration 663/1500 with 0 Insignificant Iterations
# Cost: 4781.63916015625
# Iteration 664/1500 with 0 Insignificant Iterations
# Cost: 4766.6376953125
# Iteration 665/1500 with 0 Insignificant Iterations
# Cost: 4751.72998046875
# Iteration 666/1500 with 0 Insignificant Iterations
# Cost: 4736.89501953125
# Iteration 667/1500 with 0 Insignificant Iterations
# Cost: 4722.09228515625
# Iteration 668/1500 with 0 Insignificant Iterations
# Cost: 4707.419921875
# Iteration 669/1500 with 0 Insignificant Iterations
# Cost: 4692.82568359375
# Iteration 670/1500 with 0 Insignificant Iterations
# Cost: 4678.283203125
# ...
# Iteration 1292/1500 with 0 Insignificant Iterations
# Cost: 1225.6953125
# Iteration 1293/1500 with 0 Insignificant Iterations
# Cost: 1223.568359375
# Iteration 1294/1500 with 0 Insignificant Iterations
# Cost: 1221.452392578125
# Iteration 1295/1500 with 0 Insignificant Iterations
# Cost: 1219.326904296875
# Iteration 1296/1500 with 0 Insignificant Iterations
# Cost: 1217.1807861328125
# Iteration 1297/1500 with 0 Insignificant Iterations
# Cost: 1215.0675048828125
# Iteration 1298/1500 with 0 Insignificant Iterations
# Cost: 1212.9661865234375
# Iteration 1299/1500 with 0 Insignificant Iterations
# Cost: 1210.8641357421875
# Iteration 1300/1500 with 0 Insignificant Iterations
# Cost: 1208.775146484375
# Iteration 1301/1500 with 0 Insignificant Iterations
# Cost: 1206.679931640625
# Iteration 1302/1500 with 0 Insignificant Iterations
# Cost: 1204.5947265625
# Iteration 1303/1500 with 0 Insignificant Iterations
# Cost: 1202.4896240234375
# Iteration 1304/1500 with 0 Insignificant Iterations
# Cost: 1200.391357421875
# Iteration 1305/1500 with 0 Insignificant Iterations
# Cost: 1198.3121337890625
# Iteration 1306/1500 with 0 Insignificant Iterations
# Cost: 1196.2471923828125
# Iteration 1307/1500 with 0 Insignificant Iterations
# Cost: 1194.187744140625
# Iteration 1308/1500 with 0 Insignificant Iterations
# Cost: 1192.09912109375
# Iteration 1309/1500 with 0 Insignificant Iterations
# Cost: 1190.0374755859375
# Iteration 1310/1500 with 0 Insignificant Iterations
# Cost: 1187.9876708984375
# Iteration 1311/1500 with 0 Insignificant Iterations
# Cost: 1185.9576416015625
# Iteration 1312/1500 with 0 Insignificant Iterations
# Cost: 1183.9088134765625
# Iteration 1313/1500 with 0 Insignificant Iterations
# Cost: 1181.852783203125
# Iteration 1314/1500 with 0 Insignificant Iterations
# Cost: 1179.83251953125
# Iteration 1315/1500 with 0 Insignificant Iterations
# Cost: 1177.7869873046875
# Iteration 1316/1500 with 0 Insignificant Iterations
# Cost: 1175.7623291015625
# Iteration 1317/1500 with 0 Insignificant Iterations
# Cost: 1173.7342529296875
# Iteration 1318/1500 with 0 Insignificant Iterations
# Cost: 1171.709228515625
# Iteration 1319/1500 with 0 Insignificant Iterations
# Cost: 1169.6973876953125
# Iteration 1320/1500 with 0 Insignificant Iterations
# Cost: 1167.6619873046875
# Iteration 1321/1500 with 0 Insignificant Iterations
# Cost: 1165.6500244140625
# Iteration 1322/1500 with 0 Insignificant Iterations
# Cost: 1163.654052734375
# Iteration 1323/1500 with 0 Insignificant Iterations
# Cost: 1161.647705078125
# Iteration 1324/1500 with 0 Insignificant Iterations
# Cost: 1159.6846923828125
# Iteration 1325/1500 with 0 Insignificant Iterations
# Cost: 1157.7296142578125
# Iteration 1326/1500 with 0 Insignificant Iterations
# Cost: 1155.72998046875
# Iteration 1327/1500 with 0 Insignificant Iterations
# Cost: 1153.7408447265625
# Iteration 1328/1500 with 0 Insignificant Iterations
# Cost: 1151.7158203125
# Iteration 1329/1500 with 0 Insignificant Iterations
# Cost: 1149.8056640625
# Iteration 1330/1500 with 0 Insignificant Iterations
# Cost: 1147.8787841796875
# Iteration 1331/1500 with 0 Insignificant Iterations
# Cost: 1145.8677978515625
# Iteration 1332/1500 with 0 Insignificant Iterations
# Cost: 1143.8909912109375
# Iteration 1333/1500 with 0 Insignificant Iterations
# Cost: 1141.9783935546875
# Iteration 1334/1500 with 0 Insignificant Iterations
# Cost: 1140.0462646484375
# Iteration 1335/1500 with 0 Insignificant Iterations
# Cost: 1138.091552734375
# Iteration 1336/1500 with 0 Insignificant Iterations
# Cost: 1136.1268310546875
# Iteration 1337/1500 with 0 Insignificant Iterations
# Cost: 1134.218017578125
# Iteration 1338/1500 with 0 Insignificant Iterations
# Cost: 1132.30615234375
# Iteration 1339/1500 with 0 Insignificant Iterations
# Cost: 1130.32861328125
# Iteration 1340/1500 with 0 Insignificant Iterations
# Cost: 1128.4044189453125
# Iteration 1341/1500 with 0 Insignificant Iterations
# Cost: 1126.5272216796875
# Iteration 1342/1500 with 0 Insignificant Iterations
# Cost: 1124.622802734375
# Iteration 1343/1500 with 0 Insignificant Iterations
# Cost: 1122.677978515625
# Iteration 1344/1500 with 0 Insignificant Iterations
# Cost: 1120.751708984375
# Iteration 1345/1500 with 0 Insignificant Iterations
# Cost: 1118.8775634765625
# Iteration 1346/1500 with 0 Insignificant Iterations
# Cost: 1116.996826171875
# Iteration 1347/1500 with 0 Insignificant Iterations
# Cost: 1115.091552734375
# Iteration 1348/1500 with 0 Insignificant Iterations
# Cost: 1113.21533203125
# Iteration 1349/1500 with 0 Insignificant Iterations
# Cost: 1111.32177734375
# Iteration 1350/1500 with 0 Insignificant Iterations
# Cost: 1109.47119140625
# Iteration 1351/1500 with 0 Insignificant Iterations
# Cost: 1107.5867919921875
# Iteration 1352/1500 with 0 Insignificant Iterations
# Cost: 1105.72412109375
# Iteration 1353/1500 with 0 Insignificant Iterations
# Cost: 1103.8443603515625
# Iteration 1354/1500 with 0 Insignificant Iterations
# Cost: 1101.9720458984375
# Iteration 1355/1500 with 0 Insignificant Iterations
# Cost: 1100.1243896484375
# Iteration 1356/1500 with 0 Insignificant Iterations
# Cost: 1098.2926025390625
# Iteration 1357/1500 with 0 Insignificant Iterations
# Cost: 1096.48193359375
# Iteration 1358/1500 with 0 Insignificant Iterations
# Cost: 1094.5887451171875
# Iteration 1359/1500 with 0 Insignificant Iterations
# Cost: 1092.723876953125
# Iteration 1360/1500 with 0 Insignificant Iterations
# Cost: 1090.8802490234375
# Iteration 1361/1500 with 0 Insignificant Iterations
# Cost: 1089.0916748046875
# Iteration 1362/1500 with 0 Insignificant Iterations
# Cost: 1087.247802734375
# Iteration 1363/1500 with 0 Insignificant Iterations
# Cost: 1085.373291015625
# Iteration 1364/1500 with 0 Insignificant Iterations
# Cost: 1083.5841064453125
# Iteration 1365/1500 with 0 Insignificant Iterations
# Cost: 1081.7818603515625
# Iteration 1366/1500 with 0 Insignificant Iterations
# Cost: 1079.9759521484375
# Iteration 1367/1500 with 0 Insignificant Iterations
# Cost: 1078.1561279296875
# Iteration 1368/1500 with 0 Insignificant Iterations
# Cost: 1076.338623046875
# Iteration 1369/1500 with 0 Insignificant Iterations
# Cost: 1074.5328369140625
# Iteration 1370/1500 with 0 Insignificant Iterations
# Cost: 1072.72119140625
# Iteration 1371/1500 with 0 Insignificant Iterations
# Cost: 1070.9185791015625
# Iteration 1372/1500 with 0 Insignificant Iterations
# Cost: 1069.1492919921875
# Iteration 1373/1500 with 0 Insignificant Iterations
# Cost: 1067.363037109375
# Iteration 1374/1500 with 0 Insignificant Iterations
# Cost: 1065.5802001953125
# Iteration 1375/1500 with 0 Insignificant Iterations
# Cost: 1063.7921142578125
# Iteration 1376/1500 with 0 Insignificant Iterations
# Cost: 1061.993896484375
# Iteration 1377/1500 with 0 Insignificant Iterations
# Cost: 1060.2554931640625
# Iteration 1378/1500 with 0 Insignificant Iterations
# Cost: 1058.5169677734375
# Iteration 1379/1500 with 0 Insignificant Iterations
# Cost: 1056.7413330078125
# Iteration 1380/1500 with 0 Insignificant Iterations
# Cost: 1054.975341796875
# Iteration 1381/1500 with 0 Insignificant Iterations
# Cost: 1053.254638671875
# Iteration 1382/1500 with 0 Insignificant Iterations
# Cost: 1051.5028076171875
# Iteration 1383/1500 with 0 Insignificant Iterations
# Cost: 1049.7510986328125
# Iteration 1384/1500 with 0 Insignificant Iterations
# Cost: 1048.0218505859375
# Iteration 1385/1500 with 0 Insignificant Iterations
# Cost: 1046.2777099609375
# Iteration 1386/1500 with 0 Insignificant Iterations
# Cost: 1044.5777587890625
# Iteration 1387/1500 with 0 Insignificant Iterations
# Cost: 1042.84033203125
# Iteration 1388/1500 with 0 Insignificant Iterations
# Cost: 1041.063720703125
# Iteration 1389/1500 with 0 Insignificant Iterations
# Cost: 1039.3541259765625
# Iteration 1390/1500 with 0 Insignificant Iterations
# Cost: 1037.6512451171875
# Iteration 1391/1500 with 0 Insignificant Iterations
# Cost: 1035.8984375
# Iteration 1392/1500 with 0 Insignificant Iterations
# Cost: 1034.21533203125
# Iteration 1393/1500 with 0 Insignificant Iterations
# Cost: 1032.5179443359375
# Iteration 1394/1500 with 0 Insignificant Iterations
# Cost: 1030.776123046875
# Iteration 1395/1500 with 0 Insignificant Iterations
# Cost: 1029.0860595703125
# Iteration 1396/1500 with 0 Insignificant Iterations
# Cost: 1027.4276123046875
# Iteration 1397/1500 with 0 Insignificant Iterations
# Cost: 1025.720703125
# Iteration 1398/1500 with 0 Insignificant Iterations
# Cost: 1024.0218505859375
# Iteration 1399/1500 with 0 Insignificant Iterations
# Cost: 1022.33740234375
# Iteration 1400/1500 with 0 Insignificant Iterations
# Cost: 1020.6385498046875
# Iteration 1401/1500 with 0 Insignificant Iterations
# Cost: 1018.9874877929688
# Iteration 1402/1500 with 0 Insignificant Iterations
# Cost: 1017.3262939453125
# Iteration 1403/1500 with 0 Insignificant Iterations
# Cost: 1015.6292724609375
# Iteration 1404/1500 with 0 Insignificant Iterations
# Cost: 1013.95849609375
# Iteration 1405/1500 with 0 Insignificant Iterations
# Cost: 1012.308837890625
# Iteration 1406/1500 with 0 Insignificant Iterations
# Cost: 1010.644775390625
# Iteration 1407/1500 with 0 Insignificant Iterations
# Cost: 1008.9818115234375
# Iteration 1408/1500 with 0 Insignificant Iterations
# Cost: 1007.3563842773438
# Iteration 1409/1500 with 0 Insignificant Iterations
# Cost: 1005.702880859375
# Iteration 1410/1500 with 0 Insignificant Iterations
# Cost: 1004.075927734375
# Iteration 1411/1500 with 0 Insignificant Iterations
# Cost: 1002.4226684570312
# Iteration 1412/1500 with 0 Insignificant Iterations
# Cost: 1000.7432861328125
# Iteration 1413/1500 with 0 Insignificant Iterations
# Cost: 999.1400146484375
# Iteration 1414/1500 with 0 Insignificant Iterations
# Cost: 997.5642700195312
# Iteration 1415/1500 with 0 Insignificant Iterations
# Cost: 995.9191284179688
# Iteration 1416/1500 with 0 Insignificant Iterations
# Cost: 994.2561645507812
# Iteration 1417/1500 with 0 Insignificant Iterations
# Cost: 992.6807250976562
# Iteration 1418/1500 with 0 Insignificant Iterations
# Cost: 991.0536499023438
# Iteration 1419/1500 with 0 Insignificant Iterations
# Cost: 989.4298095703125
# Iteration 1420/1500 with 0 Insignificant Iterations
# Cost: 987.8236083984375
# Iteration 1421/1500 with 0 Insignificant Iterations
# Cost: 986.2320556640625
# Iteration 1422/1500 with 0 Insignificant Iterations
# Cost: 984.6245727539062
# Iteration 1423/1500 with 0 Insignificant Iterations
# Cost: 983.0042114257812
# Iteration 1424/1500 with 0 Insignificant Iterations
# Cost: 981.4054565429688
# Iteration 1425/1500 with 0 Insignificant Iterations
# Cost: 979.8330688476562
# Iteration 1426/1500 with 0 Insignificant Iterations
# Cost: 978.2901611328125
# Iteration 1427/1500 with 0 Insignificant Iterations
# Cost: 976.6788330078125
# Iteration 1428/1500 with 0 Insignificant Iterations
# Cost: 975.090087890625
# Iteration 1429/1500 with 0 Insignificant Iterations
# Cost: 973.5299072265625
# Iteration 1430/1500 with 0 Insignificant Iterations
# Cost: 971.9684448242188
# Iteration 1431/1500 with 0 Insignificant Iterations
# Cost: 970.3894653320312
# Iteration 1432/1500 with 0 Insignificant Iterations
# Cost: 968.8407592773438
# Iteration 1433/1500 with 0 Insignificant Iterations
# Cost: 967.2568969726562
# Iteration 1434/1500 with 0 Insignificant Iterations
# Cost: 965.7369384765625
# Iteration 1435/1500 with 0 Insignificant Iterations
# Cost: 964.1741943359375
# Iteration 1436/1500 with 0 Insignificant Iterations
# Cost: 962.5964965820312
# Iteration 1437/1500 with 0 Insignificant Iterations
# Cost: 961.0526733398438
# Iteration 1438/1500 with 0 Insignificant Iterations
# Cost: 959.52294921875
# Iteration 1439/1500 with 0 Insignificant Iterations
# Cost: 957.9803466796875
# Iteration 1440/1500 with 0 Insignificant Iterations
# Cost: 956.4170532226562
# Iteration 1441/1500 with 0 Insignificant Iterations
# Cost: 954.9132080078125
# Iteration 1442/1500 with 0 Insignificant Iterations
# Cost: 953.3770751953125
# Iteration 1443/1500 with 0 Insignificant Iterations
# Cost: 951.8010864257812
# Iteration 1444/1500 with 0 Insignificant Iterations
# Cost: 950.32275390625
# Iteration 1445/1500 with 0 Insignificant Iterations
# Cost: 948.8336791992188
# Iteration 1446/1500 with 0 Insignificant Iterations
# Cost: 947.3271484375
# Iteration 1447/1500 with 0 Insignificant Iterations
# Cost: 945.78173828125
# Iteration 1448/1500 with 0 Insignificant Iterations
# Cost: 944.2376098632812
# Iteration 1449/1500 with 0 Insignificant Iterations
# Cost: 942.7750244140625
# Iteration 1450/1500 with 0 Insignificant Iterations
# Cost: 941.308837890625
# Iteration 1451/1500 with 0 Insignificant Iterations
# Cost: 939.7997436523438
# Iteration 1452/1500 with 0 Insignificant Iterations
# Cost: 938.28564453125
# Iteration 1453/1500 with 0 Insignificant Iterations
# Cost: 936.7868041992188
# Iteration 1454/1500 with 0 Insignificant Iterations
# Cost: 935.302978515625
# Iteration 1455/1500 with 0 Insignificant Iterations
# Cost: 933.7703857421875
# Iteration 1456/1500 with 0 Insignificant Iterations
# Cost: 932.337646484375
# Iteration 1457/1500 with 0 Insignificant Iterations
# Cost: 930.8333129882812
# Iteration 1458/1500 with 0 Insignificant Iterations
# Cost: 929.3298950195312
# Iteration 1459/1500 with 0 Insignificant Iterations
# Cost: 927.8723754882812
# Iteration 1460/1500 with 0 Insignificant Iterations
# Cost: 926.3882446289062
# Iteration 1461/1500 with 0 Insignificant Iterations
# Cost: 924.9488525390625
# Iteration 1462/1500 with 0 Insignificant Iterations
# Cost: 923.5123291015625
# Iteration 1463/1500 with 0 Insignificant Iterations
# Cost: 921.9917602539062
# Iteration 1464/1500 with 0 Insignificant Iterations
# Cost: 920.538818359375
# Iteration 1465/1500 with 0 Insignificant Iterations
# Cost: 919.0932006835938
# Iteration 1466/1500 with 0 Insignificant Iterations
# Cost: 917.6383056640625
# Iteration 1467/1500 with 0 Insignificant Iterations
# Cost: 916.1783447265625
# Iteration 1468/1500 with 0 Insignificant Iterations
# Cost: 914.7479248046875
# Iteration 1469/1500 with 0 Insignificant Iterations
# Cost: 913.3284301757812
# Iteration 1470/1500 with 0 Insignificant Iterations
# Cost: 911.8713989257812
# Iteration 1471/1500 with 0 Insignificant Iterations
# Cost: 910.4363403320312
# Iteration 1472/1500 with 0 Insignificant Iterations
# Cost: 909.0028686523438
# Iteration 1473/1500 with 0 Insignificant Iterations
# Cost: 907.5711669921875
# Iteration 1474/1500 with 0 Insignificant Iterations
# Cost: 906.148681640625
# Iteration 1475/1500 with 0 Insignificant Iterations
# Cost: 904.7161865234375
# Iteration 1476/1500 with 0 Insignificant Iterations
# Cost: 903.3159790039062
# Iteration 1477/1500 with 0 Insignificant Iterations
# Cost: 901.9189453125
# Iteration 1478/1500 with 0 Insignificant Iterations
# Cost: 900.4537963867188
# Iteration 1479/1500 with 0 Insignificant Iterations
# Cost: 899.0068969726562
# Iteration 1480/1500 with 0 Insignificant Iterations
# Cost: 897.6861572265625
# Iteration 1481/1500 with 0 Insignificant Iterations
# Cost: 896.2888793945312
# Iteration 1482/1500 with 0 Insignificant Iterations
# Cost: 894.8817138671875
# Iteration 1483/1500 with 0 Insignificant Iterations
# Cost: 893.4290161132812
# Iteration 1484/1500 with 0 Insignificant Iterations
# Cost: 892.0047607421875
# Iteration 1485/1500 with 0 Insignificant Iterations
# Cost: 890.663330078125
# Iteration 1486/1500 with 0 Insignificant Iterations
# Cost: 889.3069458007812
# Iteration 1487/1500 with 0 Insignificant Iterations
# Cost: 887.8975830078125
# Iteration 1488/1500 with 0 Insignificant Iterations
# Cost: 886.4826049804688
# Iteration 1489/1500 with 0 Insignificant Iterations
# Cost: 885.1265869140625
# Iteration 1490/1500 with 0 Insignificant Iterations
# Cost: 883.7569580078125
# Iteration 1491/1500 with 0 Insignificant Iterations
# Cost: 882.3394775390625
# Iteration 1492/1500 with 0 Insignificant Iterations
# Cost: 880.9923095703125
# Iteration 1493/1500 with 0 Insignificant Iterations
# Cost: 879.6502685546875
# Iteration 1494/1500 with 0 Insignificant Iterations
# Cost: 878.2698974609375
# Iteration 1495/1500 with 0 Insignificant Iterations
# Cost: 876.9041748046875
# Iteration 1496/1500 with 0 Insignificant Iterations
# Cost: 875.4993896484375
# Iteration 1497/1500 with 0 Insignificant Iterations
# Cost: 874.1617431640625
# Iteration 1498/1500 with 0 Insignificant Iterations
# Cost: 872.85888671875
# Iteration 1499/1500 with 0 Insignificant Iterations
# Cost: 871.4431762695312
# Iteration 1500/1500 with 0 Insignificant Iterations
# Cost: 870.1058349609375
# Stopping: Reached maximum number of iterations = 1500.
# Optimization Complete.
# Final Cost: 870.1058349609375

# %%
# Cost Plotting
# Plot cost history
plt.figure(figsize=(6,4))
plt.plot(cost_history, label="Cost")
plt.title("Cost History")
plt.xlabel("Iteration")
plt.ylabel("Cost")
plt.legend()
plt.grid()
plt.show()

# Logarithmic cost history
plt.figure(figsize=(6,4))
plt.plot(torch.log(torch.tensor(cost_history)), label="log(Cost)")
plt.title("Logarithmic Cost History")
plt.xlabel("Iteration")
plt.ylabel("log(Cost)")
plt.legend()
plt.grid()
plt.show()

# %%
Theta_new = ObsManager.get_all_params()
Theta_new
# Out:
# tensor([[0.0061, 0.0099],
#         [0.0083, 0.0073],
#         [0.0033, 0.0031],
#         [0.0023, 0.0036],
#         [0.0055, 0.0027],
#         [0.0052, 0.0033],
#         [0.0038, 0.0022],
#         [0.0026, 0.0074],
#         [0.0092, 0.0010],
#         [0.0068, 0.0033],
#         [0.0034, 0.0038],
#         [0.0092, 0.0029],
#         [0.0022, 0.0074],
#         [0.0014, 0.0070],
#         [0.0044, 0.0014],
#         [0.0052, 0.0045],
#         [0.0063, 0.0041],
#         [0.0058, 0.0053],
#         [0.0067, 0.0017],
#         [0.0068, 0.0028],
#         [0.0023, 0.0004],
#         [0.0017, 0.0064],
#         [0.0074, 0.0039],
#         [0.0030, 0.0008],
#         [0.0099, 0.0057],
#         [0.0089, 0.0079],
#         [0.0057, 0.0003],
#         [0.0073, 0.0079],
#         [0.0075, 0.0046],
#         [0.0075, 0.0010]])

# %% [markdown]
# ### Post-Process Optimization Results

# %%
# Use Optimal Z values to Build GP Models and Optimal A and Z matrices
optimal_Z = Z.detach()
for i in range(p):
    ObsManager.train_observable(i, Xtrain, optimal_Z[:,i])  # train GP Observables with Optimal Z outputs

ObsManager.optimize_hyperparameters()   # Optimize Kernel hyperparameters for Optimal training data

#ObsManager.plot_observables(range_x=(-3,3), range_y=(-3,3))

ObsList = [i for i in range(p)]
A, B, C = gpk.getKoopman_control(ObsManager, ObsList, X, Xplus, U, nTrain, stateAug=False)
# Out:
# c:\Users\abhig\code\KoopmanGPO-main\GPKoopman\GPObs.py:295: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\TensorShape.cpp:3687.)
#   ll = -0.5 * (self.y.T @ invK_til @ self.y + log_det + self.y.shape[0] * torch.log(torch.tensor(2 * torch.pi)))

# %% [markdown]
# ## Simulation and Validation

# %%
# Evaluation on training set
ZmeanTrain = torch.empty((nTrain, p, N))    # n+p for state-augmentation
ZcvTrain = torch.empty((nTrain, p, p, N))   # n for no state-augmentation
#ZmeanTrain[:, :n, 0] = ICsetTrain.T    # only for state-augmentation

XhatTrain = torch.empty((nTrain, n, N))
XcvhatTrain = torch.empty((nTrain, n, n, N))
TrainRMSE = torch.empty((nTrain,n))

for j in range(nTrain): # GP Predict for all training trajectories
    for i in range(p):  # GP predict IC and IC-cv
        ZmeanTrain[j, i, 0] = ObsManager.predict_mean(i, ICsetTrain[:, j].view(n,1))        # n+i for state-augmentation
        ZcvTrain[j, i, i, 0] = ObsManager.predict_covariance(i, ICsetTrain[:, j].view(n,1)) # n for no state-augmentation
    
    ZmeanTrain[j, :, :], ZcvTrain[j, :, :, :], XhatTrain[j, :, :], XcvhatTrain[j, :, :, :] = gpk.sim_LTI_nonautonomous(ZmeanTrain[j,:,0], A, B, C, SimInput[j,:,:N], num_steps=N, ts=None, x0cv=ZcvTrain[j,:,:,0])
    TrainRMSE[j,:] = torch.sqrt(torch.mean((XhatTrain[j,:,:] - SimData[j,:,:N])**2,1))


# Evaluation on test set
ZmeanTest = torch.empty((nTest, p, N))
ZcvTest = torch.empty((nTest, p, p, N))
#ZmeanTest[:, :n, 0] = ICsetTest.T  # only for state-augmentation

XhatTest = torch.empty((nTest, n, N))
XcvhatTest = torch.empty((nTest, n, n, N))
TestRMSE = torch.empty((nTest,n))

for j in range(nTest): # GP Predict for all training trajectories
    for i in range(p):  # GP predict IC and IC-cv
        ZmeanTest[j, i, 0] = ObsManager.predict_mean(i, ICsetTest[:, j].view(n,1))          # n+i for state-augmentation
        ZcvTest[j, i, i, 0] = ObsManager.predict_covariance(i, ICsetTest[:, j].view(n,1))   # n for no state-augmentation

    ZmeanTest[j, :, :], ZcvTest[j, :, :, :], XhatTest[j, :, :], XcvhatTest[j, :, :, :] = gpk.sim_LTI_nonautonomous(ZmeanTest[j,:,0], A, B, C, SimInput[nTrain+j,:,:N], num_steps=N, ts=None, x0cv=ZcvTest[j,:,:,0])
    TestRMSE[j,:] = torch.sqrt(torch.mean((XhatTest[j,:,:] - SimData[nTest+j,:,:N])**2,1))

XhatTrain, XhatTest, XcvhatTrain, XcvhatTest = XhatTrain.detach(), XhatTest.detach(), XcvhatTrain.detach(), XcvhatTest.detach()
TestRMSE, TrainRMSE = TestRMSE.detach(), TrainRMSE.detach()

# %%
# Function to compute RMSE, NLPD, and sRMSE
def compute_metrics(Xhat, Xcvhat, SimData, nTraj, N, eps=1e-6):
    RMSE = torch.sqrt(torch.mean((Xhat - SimData[:nTraj, :, :N]) ** 2, dim=2))
    
    #var_diag = Xcvhat.diagonal(dim1=1, dim2=2).permute(0, 2, 1)  # Shape (nTraj, n, N)
    
    #NLPD = torch.mean(0.5 * ((SimData[:nTraj, :, :N] - Xhat) ** 2 / var_diag + torch.log(2 * torch.pi * var_diag)), dim=2)
    
    #sRMSE = torch.sqrt(torch.mean(((SimData[:nTraj, :, :N] - Xhat) / var_diag.sqrt()) ** 2, dim=2))

    return RMSE

# Compute metrics for training set
#TrainRMSE = compute_metrics(XhatTrain, XcvhatTrain, SimData[:nTrain, :, :], nTrain, N)

# Compute metrics for test set
#TestRMSE = compute_metrics(XhatTest, XcvhatTest, SimData[nTrain:(nTrain+nTest), :, :], nTest, N)

time = torch.arange(0., ts * N, ts)
idx1 = torch.argmin(TrainRMSE.mean(dim=1))
idx2 = torch.argmin(TestRMSE.mean(dim=1))
idx3 = torch.argmax(TestRMSE.mean(dim=1))

# Best Training Trajectory Phase Plot
plt.figure(1, figsize=(6,4.5))
plt.plot(XhatTrain[idx1, 0, :], XhatTrain[idx1, 1, :], label='iGPK')
plt.plot(SimData[idx1, 0, :N], SimData[idx1, 1, :N], label='Nonlinear', linestyle='--')
plt.plot(ICsetTrain[0, idx1], ICsetTrain[1, idx1], label='IC', marker='o')
plt.title(f"Validation on Training Trajectory for {system_name}")
plt.xlabel("X1")
plt.ylabel("X2")
plt.legend()
plt.grid()
plt.show()


fig, axes = plt.subplots(n, 1, figsize=(6, 5))  # Increased figure height for better spacing
idx = idx1
fig.suptitle(f'{system_name}: States in Training with $1\\sigma$ bound')
for i in range(n):
    axes[i].fill_between(time, XhatTrain[idx, i, :] - torch.abs(XcvhatTrain[idx, i, i, :]) ** 0.5, 
                    XhatTrain[idx, i, :] + torch.abs(XcvhatTrain[idx, i, i, :]) ** 0.5, 
                    alpha=0.16, color='blue') #, label='$\\sigma$'
    # axes[i].fill_between(time, XhatTrain[idx, i, :] - 3 * XcvhatTrain[idx, i, i, :] ** 0.5, 
    #                 XhatTrain[idx, i, :] + 3 * XcvhatTrain[idx, i, i, :] ** 0.5, 
    #                 alpha=0.08, color='blue', label=f'$3\\sigma$')
    axes[i].plot(time, XhatTrain[idx, i,:], label=f'iGPK', color='blue')
    axes[i].plot(time, SimData[idx, i, :N], label=f'NL', linestyle='--', color='red')
    axes[i].set_ylabel(f'State X{i+1}')
    axes[i].legend()
    axes[i].grid()
    if i < n - 1:
        axes[i].set_xticklabels([])  # Hide x-axis labels for all but the last subplot

axes[-1].set_xlabel('Time [s]')  # Set x-label only for the bottom subplot
plt.tight_layout()
plt.show()


# Best Test Trajectory Plot
plt.figure(3,figsize=(6,4.5))
plt.plot(XhatTest[idx2, 0, :], XhatTest[idx2, 1, :], label='iGPK')
plt.plot(SimData[nTrain+idx2, 0, :N], SimData[nTrain+idx2, 1, :N], label='Nonlinear', linestyle='--')
plt.plot(ICsetTest[0, idx2], ICsetTest[1,idx2], label='IC', marker='o')
plt.title(f"Validation on Test Trajectory for {system_name}")
plt.xlabel("X1")
plt.ylabel("X2")
plt.legend()
plt.grid()
plt.show()


# Best Test Trajectory Time Plot with uncertainty bound
fig, axes = plt.subplots(n, 1, figsize=(6, 5))  # Increased figure height for better spacing
idx = idx2
fig.suptitle(f'{system_name}: States in Test with $1\\sigma$ bound')
for i in range(n):
    axes[i].fill_between(time, XhatTest[idx, i, :] - torch.abs(XcvhatTrain[idx, i, i, :]) ** 0.5, 
                    XhatTest[idx, i, :] + torch.abs(XcvhatTrain[idx, i, i, :]) ** 0.5, 
                    alpha=0.16, color='blue') #, label='$\\sigma$'
    # axes[i].fill_between(time, XhatTest[idx, i, :] - 3 * XcvhatTest[idx, i, i, :] ** 0.5, 
    #                 XhatTest[idx, i, :] + 3 * XcvhatTest[idx, i, i, :] ** 0.5, 
    #                 alpha=0.08, color='blue') #, label=f'$3\\sigma$'
    axes[i].plot(time, XhatTest[idx, i,:], label=f'iGPK', color='blue')
    axes[i].plot(time, SimData[nTrain+idx, i, :N], label=f'NL', linestyle='--', color='red')
    axes[i].set_ylabel(f'State X{i+1}')
    axes[i].legend(), axes[i].grid()
    if i < n - 1:
        axes[i].set_xticklabels([])  # Hide x-axis labels for all but the last subplot

axes[-1].set_xlabel('Time [s]')  # Set x-label only for the bottom subplot
plt.tight_layout()
plt.show()


# Worst Test Trajectory Plot
plt.figure(3,figsize=(6,4.5))
plt.plot(XhatTest[idx3, 0, :], XhatTest[idx3, 1, :], label='iGPK')
plt.plot(SimData[nTrain+idx3, 0, :N], SimData[nTrain+idx3, 1, :N], label='Nonlinear', linestyle='--')
plt.plot(ICsetTest[0, idx3], ICsetTest[1,idx3], label='IC', marker='o')
plt.title(f"Validation on Worst Test Trajectory for {system_name}")
plt.xlabel("X1")
plt.ylabel("X2")
plt.legend()
plt.grid()
plt.show()


# Worst Test Trajectory Time Plot with uncertainty bound
fig, axes = plt.subplots(n, 1, figsize=(6, 5))  # Increased figure height for better spacing
idx = idx3
fig.suptitle(f'{system_name}: States with $1\\sigma$ bound: Worst Test Trajectory')
for i in range(n):
    axes[i].fill_between(time, XhatTest[idx, i, :] - XcvhatTrain[idx, i, i, :] ** 0.5, 
                    XhatTest[idx, i, :] + XcvhatTrain[idx, i, i, :] ** 0.5, 
                    alpha=0.16, color='blue') #, label='$\\sigma$'
    # axes[i].fill_between(time, XhatTest[idx, i, :] - 3 * XcvhatTest[idx, i, i, :] ** 0.5, 
    #                 XhatTest[idx, i, :] + 3 * XcvhatTest[idx, i, i, :] ** 0.5, 
    #                 alpha=0.08, color='blue') #, label=f'$3\\sigma$'
    axes[i].plot(time, XhatTest[idx, i,:], label=f'iGPK', color='blue')
    axes[i].plot(time, SimData[nTrain+idx, i, :N], label=f'NL', linestyle='--', color='red')
    axes[i].set_ylabel(f'State X{i+1}')
    axes[i].legend(), axes[i].grid()
    if i < n - 1:
        axes[i].set_xticklabels([])  # Hide x-axis labels for all but the last subplot

axes[-1].set_xlabel('Time [s]')  # Set x-label only for the bottom subplot
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(n, 1, figsize=(6, 5))
idx = idx3
fig.suptitle(f'Predicted SD & |Error| for Worst Test Trajectory ({idx})')
for i in range(n):
    axes[i].plot(torch.abs(XcvhatTest[idx, i, i, :N-1]) ** 0.5, label='$\\sigma_X$', color='blue')
    axes[i].plot(torch.abs(SimData[nTrain+idx, i, :N-1] - XhatTest[idx, i, :N-1]), label='$\\epsilon_X$', color='red', linestyle='--')
    axes[i].set_ylabel(f'X{i+1}')
    axes[i].grid()
    axes[i].legend()
    if i < n - 1:
        axes[i].set_xticklabels([])  # Hide x-axis labels for all but the last subplot

axes[-1].set_xlabel('Time Step')  # Set x-label only for the bottom subplot
plt.tight_layout()
plt.show()

fig, axes = plt.subplots(n, 1, figsize=(6, 5))
idx = idx2
fig.suptitle(f'Predicted SD & |Error| for Best Test Trajectory ({idx})')
for i in range(n):
    axes[i].plot(torch.abs(XcvhatTest[idx, i, i, :N-1]) ** 0.5, label='$\\sigma_X$', color='blue')
    axes[i].plot(torch.abs(SimData[nTrain+idx, i, :N-1] - XhatTest[idx, i, :N-1]), label='$\\epsilon_X$', color='red', linestyle='--')
    axes[i].set_ylabel(f'X{i+1}')
    axes[i].grid()
    axes[i].legend()
    if i < n - 1:
        axes[i].set_xticklabels([])  # Hide x-axis labels for all but the last subplot

axes[-1].set_xlabel('Time Step')  # Set x-label only for the bottom subplot
plt.tight_layout()
plt.show()


# Plot Predicted Standard Deviation and Actual Error for best Test Trajectory on log scale
plt.plot(torch.log(XcvhatTest[idx3, 0, 0, :N-1] ** 0.5), label='$\\sigma_{X1}$', color='blue')
plt.plot(torch.log(XcvhatTest[idx3, 1, 1, :N-1] ** 0.5), label='$\\sigma_{X2}$', color='red')
plt.plot(torch.log(torch.abs(SimData[nTrain+idx3, 0, :N-1] - XhatTest[idx3, 0, :N-1])), label='$\\epsilon_{X1}$', color='blue', linestyle='--')
plt.plot(torch.log(torch.abs(SimData[nTrain+idx3, 1, :N-1] - XhatTest[idx3, 1, :N-1])), label='$\\epsilon_{X2}$', color='red', linestyle='--')
plt.title(f'Predicted SD and |Error| for Worst Test Trajectory ({idx3}) on log scale')
plt.legend(loc='upper right')
plt.grid()
plt.xlabel('Time Step')
plt.ylabel('log(X)')
plt.show()

# %%
# Plot Errors for all trajectories
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Training set plot
axes[0].plot(range(nTrain), TrainRMSE[:,0].numpy(), marker='o', linestyle='-', label='RMSE X1')
axes[0].plot(range(nTrain), TrainRMSE[:,1].numpy(), marker='o', linestyle='-', label='RMSE X2')
#axes[0].plot(range(nTrain), TrainNLPD.mean(dim=1).numpy(), marker='s', linestyle='-', label='NLPD')
#axes[0].plot(range(nTrain), TrainsRMSE.mean(dim=1).numpy(), marker='^', linestyle='-', label='sRMSE')
axes[0].set_title('Training Metrics')
axes[0].set_xlabel("Trajectory Index")
axes[0].set_ylabel("Metric Value")
axes[0].legend()
axes[0].grid()

# Test set plot
axes[1].plot(range(nTest), TestRMSE[:,0].numpy(), marker='o', linestyle='-', label='RMSE X1')
axes[1].plot(range(nTest), TestRMSE[:,1].numpy(), marker='o', linestyle='-', label='RMSE X2')
#axes[1].plot(range(nTest), TestNLPD.mean(dim=1).numpy(), marker='s', linestyle='-', label='NLPD')
#axes[1].plot(range(nTest), TestsRMSE.mean(dim=1).numpy(), marker='^', linestyle='-', label='sRMSE')
axes[1].set_title('Test Metrics')
axes[1].set_xlabel("Trajectory Index")
axes[1].set_ylabel("Metric Value")
axes[1].legend()
axes[1].grid()

plt.tight_layout()
plt.show()

# %%
# Eigen value plot of Koopman Matrices
eigval = torch.linalg.eigvals(A)

eigreal = eigval.real
eigimag = eigval.imag

eigreal = eigreal.detach().numpy()
eigimag = eigimag.detach().numpy()

theta = np.linspace(0, 2*np.pi, 500)
unitCirclex = np.cos(theta)
unitCircley = np.sin(theta)


fig, axes = plt.subplots(1, 2, figsize=(8, 4))
# First subplot: Eigenvalues plot
axes[0].plot(unitCirclex, unitCircley, color='red', label='Unit Circle')
axes[0].scatter(eigreal, eigimag, color='blue', label='Eigenvalues')
axes[0].axhline(0, color='black', linewidth=0.5, linestyle='--')
axes[0].axvline(0, color='black', linewidth=0.5, linestyle='--')
axes[0].set_title(f"Eigenvalues of A Matrix with {p} Observables")
axes[0].set_xlabel("Real Part")
axes[0].set_ylabel("Imaginary Part")
axes[0].grid(True)
axes[0].legend(loc='upper right')

# Second subplot: Heatmap of matrix A
im = axes[1].imshow(A.detach().numpy(), cmap='viridis', aspect='auto')
fig.colorbar(im, ax=axes[1], label="Value")
axes[1].set_title(f'{A.shape[0]}-D Koopman Matrix')
axes[1].set_xlabel("Columns")
axes[1].set_ylabel("Rows")
plt.tight_layout()
plt.show()

# %%
# Phase Diagram from all IC simulation
for j in range(SimData.shape[0]):
    plt.plot(SimData[j,0,:], SimData[j,1,:], alpha=0.5, color='blue')
    plt.plot(SimData[j,0,0], SimData[j,1,0], 'o', color='red')

plt.grid()
plt.xlabel('X1')
plt.ylabel('X2')
plt.title(f'All Trajectories: {system_name}')
plt.show()

# Training Set Predicted Trajectories
for j in range(XhatTrain.shape[0]):
    plt.plot(XhatTrain[j,0,:], XhatTrain[j,1,:], alpha=0.5, color='blue')
    plt.plot(XhatTrain[j,0,0], XhatTrain[j,1,0], 'o', color='red')

plt.grid()
plt.xlabel('X1')
plt.ylabel('X2')
plt.title(f'Predicted Trajectories - Training Set: {system_name}')
plt.show()

# %%
# # Create a 3D figure
# fig = plt.figure(figsize=(8, 6))
# ax = fig.add_subplot(111, projection='3d')

# # Plot all trajectories
# for i in range(XhatTrain.shape[0]):
#     ax.plot(XhatTrain[i, 0, :], XhatTrain[i, 1, :], XhatTrain[i, 2, :], alpha=0.7, label=f'Traj {i+1}' if i < 5 else "")
#     ax.plot(XhatTrain[i, 0, 0], XhatTrain[i, 1, 0], XhatTrain[i, 2, 0], alpha=0.7, marker='o', linestyle='None')

# # Labels and title
# ax.set_xlabel("State X1")
# ax.set_ylabel("State X2")
# ax.set_zlabel("State X3")
# ax.set_title("3D Plot of All Trajectories from iGPK Model")
